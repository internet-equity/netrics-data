# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns
import seaborn.objects as so

# %%
#imported original dataset and removed the header that initially imports with a row of data
Lizet_device = pd.read_csv('/srv/data/my_shared_data_folder/internet-equity/device_data_oct21//nm-mngd-20210511-9d9824d4.csv', header=None)
Lizet_device
# Out:
#                          0                          1             2    3   \
# 0       2021-10-27 02:51:03  nm-mngd-20210511-9d9824d4  ping_latency  rtt
# 1       2021-10-27 02:51:03  nm-mngd-20210511-9d9824d4  ping_latency  rtt
# 2       2021-10-27 02:51:03  nm-mngd-20210511-9d9824d4  ping_latency  rtt
# 3       2021-10-27 02:51:03  nm-mngd-20210511-9d9824d4  ping_latency  rtt
# 4       2021-10-27 02:51:03  nm-mngd-20210511-9d9824d4  ping_latency  rtt
# ...                     ...                        ...           ...  ...
# 620301  2021-10-17 07:14:04  nm-mngd-20210511-9d9824d4  ping_latency  rtt
# 620302  2021-10-17 03:44:05  nm-mngd-20210511-9d9824d4  ping_latency  rtt
# 620303  2021-10-17 03:44:05  nm-mngd-20210511-9d9824d4  ping_latency  rtt
# 620304  2021-10-17 03:44:05  nm-mngd-20210511-9d9824d4  ping_latency  rtt
# 620305  2021-10-17 03:44:05  nm-mngd-20210511-9d9824d4  ping_latency  rtt
#
#           4        5    6     7      8        9       10    11           12  \
# ...

# %%
#renamed the columns to match original dataset
Lizet_device.rename(columns={0:'time', 1:'deviceid', 2:'tool', 3:'direction', 4:'protocol', 5:'target', 6:'pktloss', 7:'method', 8:'zip', 9:'isp', 10:'value', 11:'topic', 12:'annonipaddr', 13:'ipaddrchanged'}, inplace = True)
Lizet_device
# Out:
#                        time                   deviceid          tool  \
# 0       2021-10-27 02:51:03  nm-mngd-20210511-9d9824d4  ping_latency
# 1       2021-10-27 02:51:03  nm-mngd-20210511-9d9824d4  ping_latency
# 2       2021-10-27 02:51:03  nm-mngd-20210511-9d9824d4  ping_latency
# 3       2021-10-27 02:51:03  nm-mngd-20210511-9d9824d4  ping_latency
# 4       2021-10-27 02:51:03  nm-mngd-20210511-9d9824d4  ping_latency
# ...                     ...                        ...           ...
# 620301  2021-10-17 07:14:04  nm-mngd-20210511-9d9824d4  ping_latency
# 620302  2021-10-17 03:44:05  nm-mngd-20210511-9d9824d4  ping_latency
# 620303  2021-10-17 03:44:05  nm-mngd-20210511-9d9824d4  ping_latency
# 620304  2021-10-17 03:44:05  nm-mngd-20210511-9d9824d4  ping_latency
# 620305  2021-10-17 03:44:05  nm-mngd-20210511-9d9824d4  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# ...

# %%
#filter dataset by location 'Atlanta'
Lizet_device_At = Lizet_device.loc[Lizet_device['target'] == 'Atlanta']
Lizet_device_At
# Out:
#                        time                   deviceid          tool  \
# 0       2021-10-27 02:51:03  nm-mngd-20210511-9d9824d4  ping_latency
# 1       2021-10-27 02:51:03  nm-mngd-20210511-9d9824d4  ping_latency
# 2       2021-10-27 02:51:03  nm-mngd-20210511-9d9824d4  ping_latency
# 3       2021-10-27 02:51:03  nm-mngd-20210511-9d9824d4  ping_latency
# 81      2021-10-27 14:11:00  nm-mngd-20210511-9d9824d4  ping_latency
# ...                     ...                        ...           ...
# 620143  2021-10-17 13:06:00  nm-mngd-20210511-9d9824d4  ping_latency
# 620217  2021-10-16 20:01:01  nm-mngd-20210511-9d9824d4  ping_latency
# 620218  2021-10-16 20:01:01  nm-mngd-20210511-9d9824d4  ping_latency
# 620219  2021-10-16 20:01:01  nm-mngd-20210511-9d9824d4  ping_latency
# 620220  2021-10-16 20:01:01  nm-mngd-20210511-9d9824d4  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# ...

# %%
#filter dataset to show max method
Lizet_device_max = Lizet_device_At.loc[Lizet_device_At['method'] == 'max']
Lizet_device_max
# Out:
#                        time                   deviceid          tool  \
# 1       2021-10-27 02:51:03  nm-mngd-20210511-9d9824d4  ping_latency
# 82      2021-10-27 14:11:00  nm-mngd-20210511-9d9824d4  ping_latency
# 159     2021-10-27 01:31:00  nm-mngd-20210511-9d9824d4  ping_latency
# 236     2021-10-27 18:21:00  nm-mngd-20210511-9d9824d4  ping_latency
# 313     2021-10-27 14:20:59  nm-mngd-20210511-9d9824d4  ping_latency
# ...                     ...                        ...           ...
# 619906  2021-10-17 01:00:59  nm-mngd-20210511-9d9824d4  ping_latency
# 619983  2021-10-17 13:45:59  nm-mngd-20210511-9d9824d4  ping_latency
# 620060  2021-10-17 14:11:00  nm-mngd-20210511-9d9824d4  ping_latency
# 620141  2021-10-17 13:06:00  nm-mngd-20210511-9d9824d4  ping_latency
# 620218  2021-10-16 20:01:01  nm-mngd-20210511-9d9824d4  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# ...

# %%
#create two new columns to separate the date and time hour from the time column
def split_hour(x):
    row = x
    return row[11:13]

def split_date(x):
    row = x
    return row[5:10]

Lizet_device_max['hour'] = Lizet_device_max['time'].apply(split_hour)
Lizet_device_max['date'] = Lizet_device_max['time'].apply(split_date)
Lizet_device_max
# Out:
# /tmp/ipykernel_1306715/3713593664.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Lizet_device_max['hour'] = Lizet_device_max['time'].apply(split_hour)
# /tmp/ipykernel_1306715/3713593664.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Lizet_device_max['date'] = Lizet_device_max['time'].apply(split_date)
#                        time                   deviceid          tool  \
# 1       2021-10-27 02:51:03  nm-mngd-20210511-9d9824d4  ping_latency
# ...

# %%
#random date selection
Lizet_device_max['date'].sample(7, replace=False)
# Out:
# 4600      10-27
# 50851     10-18
# 37078     10-15
# 520712    10-28
# 419009    10-13
# 513307    10-28
# 174689    10-30
# Name: date, dtype: object

# %%
#change hour from str to int
Lizet_device_max.hour = Lizet_device_max['hour'].astype('int')
print(Lizet_device_max.dtypes)
# Out:
# time              object
# deviceid          object
# tool              object
# direction         object
# protocol          object
# target            object
# pktloss          float64
# method            object
# zip                int64
# isp               object
# value            float64
# topic             object
# annonipaddr       object
# ipaddrchanged      int64
# hour               int64
# date              object
# dtype: object
# /tmp/ipykernel_1306715/3258972154.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Lizet_device_max.hour = Lizet_device_max['hour'].astype('int')

# %%
#dataframe for day 1
day1 = Lizet_device_max.loc[Lizet_device_max['date'] == '10-27']
day1
# Out:
#                        time                   deviceid          tool  \
# 1       2021-10-27 02:51:03  nm-mngd-20210511-9d9824d4  ping_latency
# 82      2021-10-27 14:11:00  nm-mngd-20210511-9d9824d4  ping_latency
# 159     2021-10-27 01:31:00  nm-mngd-20210511-9d9824d4  ping_latency
# 236     2021-10-27 18:21:00  nm-mngd-20210511-9d9824d4  ping_latency
# 313     2021-10-27 14:20:59  nm-mngd-20210511-9d9824d4  ping_latency
# ...                     ...                        ...           ...
# 527122  2021-10-27 21:41:00  nm-mngd-20210511-9d9824d4  ping_latency
# 527199  2021-10-27 22:15:59  nm-mngd-20210511-9d9824d4  ping_latency
# 528435  2021-10-27 23:01:00  nm-mngd-20210511-9d9824d4  ping_latency
# 530234  2021-10-27 23:15:59  nm-mngd-20210511-9d9824d4  ping_latency
# 530854  2021-10-27 23:56:00  nm-mngd-20210511-9d9824d4  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# ...

# %%
#dataframe for day 2
day2 = Lizet_device_max.loc[Lizet_device_max['date'] == '10-18']
day2
# Out:
#                        time                   deviceid          tool  \
# 44923   2021-10-18 11:26:00  nm-mngd-20210511-9d9824d4  ping_latency
# 45004   2021-10-18 15:56:01  nm-mngd-20210511-9d9824d4  ping_latency
# 45081   2021-10-18 03:06:00  nm-mngd-20210511-9d9824d4  ping_latency
# 45158   2021-10-18 12:26:00  nm-mngd-20210511-9d9824d4  ping_latency
# 45235   2021-10-18 10:25:59  nm-mngd-20210511-9d9824d4  ping_latency
# ...                     ...                        ...           ...
# 455397  2021-10-18 21:11:02  nm-mngd-20210511-9d9824d4  ping_latency
# 455634  2021-10-18 19:51:02  nm-mngd-20210511-9d9824d4  ping_latency
# 455869  2021-10-18 23:41:00  nm-mngd-20210511-9d9824d4  ping_latency
# 456254  2021-10-18 19:31:01  nm-mngd-20210511-9d9824d4  ping_latency
# 456331  2021-10-18 23:15:59  nm-mngd-20210511-9d9824d4  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# ...

# %%
#dataframe for day 3
day3 = Lizet_device_max.loc[Lizet_device_max['date'] == '10-28']
day3
# Out:
#                        time                   deviceid          tool  \
# 390208  2021-10-28 19:40:59  nm-mngd-20210511-9d9824d4  ping_latency
# 390516  2021-10-28 22:00:59  nm-mngd-20210511-9d9824d4  ping_latency
# 390986  2021-10-28 20:00:59  nm-mngd-20210511-9d9824d4  ping_latency
# 391298  2021-10-28 19:26:00  nm-mngd-20210511-9d9824d4  ping_latency
# 391687  2021-10-28 21:25:59  nm-mngd-20210511-9d9824d4  ping_latency
# ...                     ...                        ...           ...
# 530465  2021-10-28 17:11:00  nm-mngd-20210511-9d9824d4  ping_latency
# 530542  2021-10-28 18:45:59  nm-mngd-20210511-9d9824d4  ping_latency
# 530623  2021-10-28 06:20:59  nm-mngd-20210511-9d9824d4  ping_latency
# 530700  2021-10-28 16:46:00  nm-mngd-20210511-9d9824d4  ping_latency
# 530777  2021-10-28 07:46:00  nm-mngd-20210511-9d9824d4  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# ...

# %%
#dataframe for day 4
day4 = Lizet_device_max.loc[Lizet_device_max['date'] == '10-23']
day4
# Out:
#                        time                   deviceid          tool  \
# 110625  2021-10-23 21:01:00  nm-mngd-20210511-9d9824d4  ping_latency
# 111087  2021-10-23 23:31:01  nm-mngd-20210511-9d9824d4  ping_latency
# 111164  2021-10-23 21:16:00  nm-mngd-20210511-9d9824d4  ping_latency
# 111395  2021-10-23 19:15:59  nm-mngd-20210511-9d9824d4  ping_latency
# 111857  2021-10-23 21:55:59  nm-mngd-20210511-9d9824d4  ping_latency
# ...                     ...                        ...           ...
# 389434  2021-10-23 17:56:00  nm-mngd-20210511-9d9824d4  ping_latency
# 389511  2021-10-23 02:46:00  nm-mngd-20210511-9d9824d4  ping_latency
# 389588  2021-10-23 16:01:00  nm-mngd-20210511-9d9824d4  ping_latency
# 389665  2021-10-23 09:26:01  nm-mngd-20210511-9d9824d4  ping_latency
# 389742  2021-10-23 07:01:00  nm-mngd-20210511-9d9824d4  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# ...

# %%
#dataframe for day 5
day5 = Lizet_device_max.loc[Lizet_device_max['date'] == '10-14']
day5
# Out:
#                        time                   deviceid          tool  \
# 22600   2021-10-14 20:16:00  nm-mngd-20210511-9d9824d4  ping_latency
# 22835   2021-10-14 22:41:00  nm-mngd-20210511-9d9824d4  ping_latency
# 23023   2021-10-14 19:55:59  nm-mngd-20210511-9d9824d4  ping_latency
# 23339   2021-10-14 21:16:00  nm-mngd-20210511-9d9824d4  ping_latency
# 23416   2021-10-14 23:31:01  nm-mngd-20210511-9d9824d4  ping_latency
# ...                     ...                        ...           ...
# 507719  2021-10-14 14:20:59  nm-mngd-20210511-9d9824d4  ping_latency
# 507873  2021-10-14 16:11:01  nm-mngd-20210511-9d9824d4  ping_latency
# 507950  2021-10-14 16:06:01  nm-mngd-20210511-9d9824d4  ping_latency
# 508027  2021-10-14 17:51:01  nm-mngd-20210511-9d9824d4  ping_latency
# 508258  2021-10-14 15:51:01  nm-mngd-20210511-9d9824d4  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# ...

# %%
#dataframe for day 6
day6 = Lizet_device_max.loc[Lizet_device_max['date'] == '10-30']
day6
# Out:
#                        time                   deviceid          tool  \
# 155077  2021-10-30 16:16:00  nm-mngd-20210511-9d9824d4  ping_latency
# 155154  2021-10-30 08:06:04  nm-mngd-20210511-9d9824d4  ping_latency
# 155235  2021-10-30 02:51:00  nm-mngd-20210511-9d9824d4  ping_latency
# 155312  2021-10-30 01:05:59  nm-mngd-20210511-9d9824d4  ping_latency
# 155389  2021-10-30 06:41:00  nm-mngd-20210511-9d9824d4  ping_latency
# ...                     ...                        ...           ...
# 574611  2021-10-30 21:36:00  nm-mngd-20210511-9d9824d4  ping_latency
# 574765  2021-10-30 19:35:59  nm-mngd-20210511-9d9824d4  ping_latency
# 574919  2021-10-30 22:36:00  nm-mngd-20210511-9d9824d4  ping_latency
# 575154  2021-10-30 21:10:59  nm-mngd-20210511-9d9824d4  ping_latency
# 575308  2021-10-30 23:06:01  nm-mngd-20210511-9d9824d4  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# ...

# %%
#dataframe for day 7
day7 = Lizet_device_max.loc[Lizet_device_max['date'] == '10-26']
day7
# Out:
#                        time                   deviceid          tool  \
# 941     2021-10-26 22:56:01  nm-mngd-20210511-9d9824d4  ping_latency
# 1018    2021-10-26 23:25:59  nm-mngd-20210511-9d9824d4  ping_latency
# 2736    2021-10-26 23:00:59  nm-mngd-20210511-9d9824d4  ping_latency
# 2967    2021-10-26 23:31:00  nm-mngd-20210511-9d9824d4  ping_latency
# 3591    2021-10-26 21:25:59  nm-mngd-20210511-9d9824d4  ping_latency
# ...                     ...                        ...           ...
# 501416  2021-10-26 00:21:02  nm-mngd-20210511-9d9824d4  ping_latency
# 501497  2021-10-26 07:31:02  nm-mngd-20210511-9d9824d4  ping_latency
# 501574  2021-10-26 12:36:00  nm-mngd-20210511-9d9824d4  ping_latency
# 501651  2021-10-26 00:36:02  nm-mngd-20210511-9d9824d4  ping_latency
# 501728  2021-10-26 07:46:01  nm-mngd-20210511-9d9824d4  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# ...

# %%
#Create 7 time series plots. 1 for each day - this one didn't work
fig,ax =  plt.subplots( 4, 2,
                       figsize = ( 10, 8))
  
sns.lineplot( x = "hour", y = "value", 
             color = 'r', data = day1, 
             ax = ax[0][0])
ax[0][0].tick_params(labelrotation = 25)
plt.xticks(np.arange(min(day1min), max(day1max)+1, 1.0))

sns.lineplot( x = "hour", y = "value", 
             color = 'g', data = day2,
             ax = ax[0][1])
ax[0][1].tick_params(labelrotation = 25)

sns.lineplot(x = "hour", y = "value", 
             color = 'b', data = day3,
             ax = ax[1][0])
ax[1][0].tick_params(labelrotation = 25)

sns.lineplot(x = "hour", y = "value", 
             color = 'y', data = day4, 
             ax = ax[1][1])
ax[1][1].tick_params(labelrotation = 25)

sns.lineplot( x = "hour", y = "value", 
             color = 'purple', data = day5, 
             ax = ax[2][0])
ax[2][0].tick_params(labelrotation = 25)

sns.lineplot( x = "hour", y = "value", 
             color = 'magenta', data = day6, 
             ax = ax[2][1])
ax[2][1].tick_params(labelrotation = 25)

sns.lineplot( x = "hour", y = "value", 
             color = 'orange', data = day7, 
             ax = ax[3][0])
ax[3][0].tick_params(labelrotation = 25)

plt.xticks

fig.tight_layout(pad = 1.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 9
#       5 sns.lineplot( x = "hour", y = "value",
#       6              color = 'r', data = day1,
#       7              ax = ax[0][0])
#       8 ax[0][0].tick_params(labelrotation = 25)
# ----> 9 plt.xticks(np.arange(min(day1min), max(day1max)+1, 1.0))
#      11 sns.lineplot( x = "hour", y = "value",
#      12              color = 'g', data = day2,
#      13              ax = ax[0][1])
#      14 ax[0][1].tick_params(labelrotation = 25)
#
# NameError: name 'day1min' is not defined

# %%
#creawte a time series plot for each date - This one worked
fig,ax =  plt.subplots( 4, 2,
                       figsize = ( 15, 15))
  
sns.lineplot( x = "hour", y = "value", 
             color = 'r', data = day1, 
             ax = ax[0][0])
ax[0][0].tick_params(labelrotation = 25)
plt.xticks(np.arange(min(Lizet_device_max['hour']), max(Lizet_device_max['hour'])+1, 1.0))

sns.lineplot( x = "hour", y = "value", 
             color = 'g', data = day2,
             ax = ax[0][1])
ax[0][1].tick_params(labelrotation = 25)
plt.xticks(np.arange(min(Lizet_device_max['hour']), max(Lizet_device_max['hour'])+1, 1.0))

sns.lineplot(x = "hour", y = "value", 
             color = 'b', data = day3,
             ax = ax[1][0])
ax[1][0].tick_params(labelrotation = 25)
plt.xticks(np.arange(min(Lizet_device_max['hour']), max(Lizet_device_max['hour'])+1, 1.0))


sns.lineplot(x = "hour", y = "value", 
             color = 'y', data = day4, 
             ax = ax[1][1])
ax[1][1].tick_params(labelrotation = 25)
plt.xticks(np.arange(min(Lizet_device_max['hour']), max(Lizet_device_max['hour'])+1, 1.0))

sns.lineplot( x = "hour", y = "value", 
             color = 'purple', data = day5, 
             ax = ax[2][0])
ax[2][0].tick_params(labelrotation = 25)
plt.xticks(np.arange(min(Lizet_device_max['hour']), max(Lizet_device_max['hour'])+1, 1.0))

sns.lineplot( x = "hour", y = "value", 
             color = 'magenta', data = day6, 
             ax = ax[2][1])
ax[2][1].tick_params(labelrotation = 25)
plt.xticks(np.arange(min(Lizet_device_max['hour']), max(Lizet_device_max['hour'])+1, 1.0))

sns.lineplot( x = "hour", y = "value", 
             color = 'orange', data = day7, 
             ax = ax[3][0])
ax[3][0].tick_params(labelrotation = 25)
plt.xticks(np.arange(min(Lizet_device_max['hour']), max(Lizet_device_max['hour'])+1, 1.0))


fig.tight_layout(pad = 1.2)

# %%
#Create a function that counts the number of anomalies per our chosen threshold.
def anomaly_detect(parameter1):
    anomaly_count = 0
    if parameter1 >= 42:
        anomaly_count += 1
    else:
        pass
    return anomaly_count

# %%
anomaly_sum_10_27 = day1["value"].apply(anomaly_detect)
anomaly_sum_10_27
# Out:
# 1         0
# 82        1
# 159       0
# 236       0
# 313       1
#          ..
# 527122    1
# 527199    0
# 528435    0
# 530234    0
# 530854    0
# Name: value, Length: 288, dtype: int64

# %%
#This gives you the number of anomalies per day on one day

# %%
#Added a column to the original cleaned df that ticks if the latency value meet or exceeds the given threshold
Lizet_device_max['anomalyttl'] = Lizet_device_max['value'].apply(anomaly_detect)
# Out:
# /tmp/ipykernel_1306715/579352136.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Lizet_device_max['anomalyttl'] = Lizet_device_max['value'].apply(anomaly_detect)

# %%
Lizet_device_max
# Out:
#                        time                   deviceid          tool  \
# 1       2021-10-27 02:51:03  nm-mngd-20210511-9d9824d4  ping_latency
# 82      2021-10-27 14:11:00  nm-mngd-20210511-9d9824d4  ping_latency
# 159     2021-10-27 01:31:00  nm-mngd-20210511-9d9824d4  ping_latency
# 236     2021-10-27 18:21:00  nm-mngd-20210511-9d9824d4  ping_latency
# 313     2021-10-27 14:20:59  nm-mngd-20210511-9d9824d4  ping_latency
# ...                     ...                        ...           ...
# 619906  2021-10-17 01:00:59  nm-mngd-20210511-9d9824d4  ping_latency
# 619983  2021-10-17 13:45:59  nm-mngd-20210511-9d9824d4  ping_latency
# 620060  2021-10-17 14:11:00  nm-mngd-20210511-9d9824d4  ping_latency
# 620141  2021-10-17 13:06:00  nm-mngd-20210511-9d9824d4  ping_latency
# 620218  2021-10-16 20:01:01  nm-mngd-20210511-9d9824d4  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# ...

# %%
#this df groups each date and creates a total count of all the anomalies on each date
anomaly_df = Lizet_device_max.groupby('date')[['anomalyttl']].sum()

# %%
anomaly_df
# Out:
#        anomalyttl
# date
# 09-30          15
# 10-01          59
# 10-02          87
# 10-03          82
# 10-04          67
# 10-05          55
# 10-06          70
# 10-07          55
# 10-08          42
# 10-11          57
# 10-12          64
# 10-13          39
# 10-14          17
# 10-15          74
# 10-16          63
# 10-17          55
# 10-18          49
# 10-19          53
# 10-20          37
# 10-21          61
# 10-22          66
# 10-23          60
# 10-24          82
# 10-25          49
# 10-26          56
# 10-27          62
# 10-28          57
# 10-29          57
# 10-30          61
# 10-31          64

# %%
sns.lineplot( x = "time", y = "value", 
             color = 'r', data = day7 )
plt.tick_params(labelrotation = 25)
plt.xticks(np.arange(1,288, 24))
# Out:
# ([<matplotlib.axis.XTick at 0x7fbd77349490>,
# ...
#  [Text(1, 0, '2021-10-26 23:25:59'),
#   Text(25, 0, '2021-10-26 22:16:00'),
#   Text(49, 0, '2021-10-26 22:51:00'),
#   Text(73, 0, '2021-10-26 08:55:59'),
#   Text(97, 0, '2021-10-26 10:11:04'),
#   Text(121, 0, '2021-10-26 06:56:01'),
#   Text(145, 0, '2021-10-26 14:15:59'),
#   Text(169, 0, '2021-10-26 17:26:00'),
#   Text(193, 0, '2021-10-26 12:20:59'),
#   Text(217, 0, '2021-10-26 17:20:59'),
#   Text(241, 0, '2021-10-26 07:41:03'),
#   Text(265, 0, '2021-10-26 04:46:02')])

# %%
#This code plots 7 time series graphs with the correct x variable of time.
fig,ax =  plt.subplots( 4, 2,
                       figsize = ( 15, 15))
  
sns.lineplot( x = "time", y = "value", 
             color = 'r', data = day1, 
             ax = ax[0][0])
ax[0][0].tick_params(labelrotation = 25)
plt.xticks(np.arange(1,288, 24))

sns.lineplot( x = "time", y = "value", 
             color = 'g', data = day2,
             ax = ax[0][1])
ax[0][1].tick_params(labelrotation = 25)
plt.xticks(np.arange(1,288, 24))

sns.lineplot(x = "time", y = "value", 
             color = 'b', data = day3,
             ax = ax[1][0])
ax[1][0].tick_params(labelrotation = 25)
plt.xticks(np.arange(1,288, 24))


sns.lineplot(x = "time", y = "value", 
             color = 'y', data = day4, 
             ax = ax[1][1])
ax[1][1].tick_params(labelrotation = 25)
plt.xticks(np.arange(1,288, 24))

sns.lineplot( x = "time", y = "value", 
             color = 'purple', data = day5, 
             ax = ax[2][0])
ax[2][0].tick_params(labelrotation = 25)
plt.xticks(np.arange(1,288, 24))

sns.lineplot( x = "time", y = "value", 
             color = 'magenta', data = day6, 
             ax = ax[2][1])
ax[2][1].tick_params(labelrotation = 25)
plt.xticks(np.arange(1,288, 24))

sns.lineplot( x = "time", y = "value", 
             color = 'orange', data = day7, 
             ax = ax[3][0])
ax[3][0].tick_params(labelrotation = 25)
plt.xticks(np.arange(1,288, 24))


fig.tight_layout(pad = 1.2)

# %%
#Create a function that counts the number of anomalies per our chosen threshold. - changed threshold to 50
def anomaly_detect(parameter1):
    anomaly_count = 0
    if parameter1 >= 50:
        anomaly_count += 1
    else:
        pass
    return anomaly_count

# %%
#Added a column to the original cleaned df that ticks if the latency value meet or exceeds the given threshold
Lizet_device_max['anomalyttl'] = Lizet_device_max['value'].apply(anomaly_detect)
# Out:
# /tmp/ipykernel_1306715/579352136.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Lizet_device_max['anomalyttl'] = Lizet_device_max['value'].apply(anomaly_detect)

# %%
#this df groups each date and creates a total count of all the anomalies on each date - adjusted to new threshold

anomaly_df = Lizet_device_max.groupby('date')[['anomalyttl']].sum()
anomaly_df
# Out:
#        anomalyttl
# date
# 09-30           0
# 10-01           2
# 10-02           3
# 10-03           2
# 10-04           4
# 10-05           2
# 10-06           1
# 10-07           4
# 10-08           1
# 10-11           3
# 10-12           3
# 10-13           0
# 10-14           1
# 10-15           3
# 10-16           0
# 10-17           1
# 10-18           1
# 10-19           2
# 10-20           3
# 10-21           3
# 10-22           2
# 10-23           3
# 10-24           2
# 10-25           2
# 10-26           7
# 10-27           3
# 10-28           1
# 10-29           2
# 10-30           0
# 10-31           4
