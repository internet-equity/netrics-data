# %%
# First thing, Copy the code from the previous day "SingledeviceRC"
# That branch has the code that we will still be working on today.
# Essentially my dataframe is a singular device that is recording the max, min, avg, and mdev latency every 5 minutes for the month of october.

# %%
#This cell imports the entire dataframe from the one device for the month of october 
import pandas as pd
import numpy as np
rc_device = pd.read_csv('/srv/data/my_shared_data_folder/internet-equity/device_data_oct21/nm-mngd-20210518-075ab2f0.csv')
rc_device
# Out:
#         2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency  rtt  \
# 0       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency  rtt
# 1       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency  rtt
# 2       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency  rtt
# 3       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency  rtt
# 4       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency  rtt
# ...                     ...                        ...            ...  ...
# 469526  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt  rtt
# 469527  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt  rtt
# 469528  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt  rtt
# 469529  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt  rtt
# 469530  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt  rtt
#
#         icmp     Atlanta    0        avg  60615  xfinity  37.488  beta  \
# 0       icmp     Atlanta  0.0        max  60615  xfinity  40.056  beta
# 1       icmp     Atlanta  0.0       mdev  60615  xfinity   1.094  beta
# 2       icmp     Atlanta  0.0        min  60615  xfinity  36.042  beta
# 3       icmp     Chicago  0.0        avg  60615  xfinity  12.619  beta
# 4       icmp     Chicago  0.0        max  60615  xfinity  13.832  beta
# ...      ...         ...  ...        ...    ...      ...     ...   ...
# 469526  icmp  Cloudflare  0.0  ping_mdev  60615  xfinity   0.396  beta
# 469527  icmp  Cloudflare  0.0   ping_min  60615  xfinity   8.436  beta
# 469528  icmp  Cloudflare  0.0     tr_max  60615  xfinity   8.597  beta
# 469529  icmp  Cloudflare  0.0  tr_median  60615  xfinity   8.589  beta
# 469530  icmp  Cloudflare  0.0     tr_min  60615  xfinity   8.531  beta
#
#         98.206.160.0  0.1
# 0       98.206.160.0    0
# 1       98.206.160.0    0
# 2       98.206.160.0    0
# 3       98.206.160.0    0
# 4       98.206.160.0    0
# ...              ...  ...
# 469526  98.206.160.0    0
# 469527  98.206.160.0    0
# 469528  98.206.160.0    0
# 469529  98.206.160.0    0
# 469530  98.206.160.0    0
#
# [469531 rows x 14 columns]

# %%
# However the header of the column is an actual row, and should be within the dataframe not the header of the data frame 
# I am going to set the header to none which will put the previous header within the dataframe and then I am going to rename the columns the correct names
import pandas as pd
import numpy as np
rc_device = pd.read_csv('/srv/data/my_shared_data_folder/internet-equity/device_data_oct21/nm-mngd-20210518-075ab2f0.csv', header=None)
rc_device
rc_device.rename(columns={0:'time',1:'deviceid',2:'tool',3:'direction',4:'protocol',5:'target',6:'pktloss',7:'method',8:'zip',9:'isp',10:'value',11:'topic',12:'annonipaddr',13:'ipaddrchanged'},inplace=True)
rc_device
# Out:
#                        time                   deviceid           tool  \
# 0       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency
# 1       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency
# 2       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency
# 3       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency
# 4       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency
# ...                     ...                        ...            ...
# 469527  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt
# 469528  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt
# 469529  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt
# 469530  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt
# 469531  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt
#
#        direction protocol      target  pktloss     method    zip      isp  \
# 0            rtt     icmp     Atlanta      0.0        avg  60615  xfinity
# 1            rtt     icmp     Atlanta      0.0        max  60615  xfinity
# 2            rtt     icmp     Atlanta      0.0       mdev  60615  xfinity
# 3            rtt     icmp     Atlanta      0.0        min  60615  xfinity
# 4            rtt     icmp     Chicago      0.0        avg  60615  xfinity
# ...          ...      ...         ...      ...        ...    ...      ...
# 469527       rtt     icmp  Cloudflare      0.0  ping_mdev  60615  xfinity
# 469528       rtt     icmp  Cloudflare      0.0   ping_min  60615  xfinity
# 469529       rtt     icmp  Cloudflare      0.0     tr_max  60615  xfinity
# 469530       rtt     icmp  Cloudflare      0.0  tr_median  60615  xfinity
# 469531       rtt     icmp  Cloudflare      0.0     tr_min  60615  xfinity
#
#          value topic   annonipaddr  ipaddrchanged
# 0       37.488  beta  98.206.160.0              0
# 1       40.056  beta  98.206.160.0              0
# 2        1.094  beta  98.206.160.0              0
# 3       36.042  beta  98.206.160.0              0
# 4       12.619  beta  98.206.160.0              0
# ...        ...   ...           ...            ...
# 469527   0.396  beta  98.206.160.0              0
# 469528   8.436  beta  98.206.160.0              0
# 469529   8.597  beta  98.206.160.0              0
# 469530   8.589  beta  98.206.160.0              0
# 469531   8.531  beta  98.206.160.0              0
#
# [469532 rows x 14 columns]

# %%
#seperate the data and hours(why), make each a column and add both as two seperate columns at the end of the dataframe.
#Accomplished this by making a function 
def split_hour(x):
    row = x
    return row[11:13]

rc_device.loc[:,"hour"] = rc_device.loc[:,"time"].apply(split_hour)
rc_device
# Out:
#                        time                   deviceid           tool  \
# 0       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency
# 1       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency
# 2       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency
# 3       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency
# 4       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency
# ...                     ...                        ...            ...
# 469527  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt
# 469528  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt
# 469529  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt
# 469530  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt
# 469531  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt
#
#        direction protocol      target  pktloss     method    zip      isp  \
# 0            rtt     icmp     Atlanta      0.0        avg  60615  xfinity
# 1            rtt     icmp     Atlanta      0.0        max  60615  xfinity
# 2            rtt     icmp     Atlanta      0.0       mdev  60615  xfinity
# 3            rtt     icmp     Atlanta      0.0        min  60615  xfinity
# 4            rtt     icmp     Chicago      0.0        avg  60615  xfinity
# ...          ...      ...         ...      ...        ...    ...      ...
# 469527       rtt     icmp  Cloudflare      0.0  ping_mdev  60615  xfinity
# 469528       rtt     icmp  Cloudflare      0.0   ping_min  60615  xfinity
# 469529       rtt     icmp  Cloudflare      0.0     tr_max  60615  xfinity
# 469530       rtt     icmp  Cloudflare      0.0  tr_median  60615  xfinity
# 469531       rtt     icmp  Cloudflare      0.0     tr_min  60615  xfinity
#
#          value topic   annonipaddr  ipaddrchanged hour
# 0       37.488  beta  98.206.160.0              0   03
# 1       40.056  beta  98.206.160.0              0   03
# 2        1.094  beta  98.206.160.0              0   03
# 3       36.042  beta  98.206.160.0              0   03
# 4       12.619  beta  98.206.160.0              0   03
# ...        ...   ...           ...            ...  ...
# 469527   0.396  beta  98.206.160.0              0   06
# 469528   8.436  beta  98.206.160.0              0   06
# 469529   8.597  beta  98.206.160.0              0   06
# 469530   8.589  beta  98.206.160.0              0   06
# 469531   8.531  beta  98.206.160.0              0   06
#
# [469532 rows x 15 columns]

# %%
#do the same thing that we did previously but with dates
def split_date(x):
    row = x
    return row[:10]

rc_device.loc[:,"date"] = rc_device.loc[:,"time"].apply(split_date)
rc_device
#now we have two new columns with just the date and just the hour.
# Out:
#                        time                   deviceid           tool  \
# 0       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency
# 1       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency
# 2       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency
# 3       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency
# 4       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency
# ...                     ...                        ...            ...
# 469527  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt
# 469528  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt
# 469529  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt
# 469530  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt
# 469531  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt
#
#        direction protocol      target  pktloss     method    zip      isp  \
# 0            rtt     icmp     Atlanta      0.0        avg  60615  xfinity
# 1            rtt     icmp     Atlanta      0.0        max  60615  xfinity
# 2            rtt     icmp     Atlanta      0.0       mdev  60615  xfinity
# 3            rtt     icmp     Atlanta      0.0        min  60615  xfinity
# 4            rtt     icmp     Chicago      0.0        avg  60615  xfinity
# ...          ...      ...         ...      ...        ...    ...      ...
# 469527       rtt     icmp  Cloudflare      0.0  ping_mdev  60615  xfinity
# 469528       rtt     icmp  Cloudflare      0.0   ping_min  60615  xfinity
# 469529       rtt     icmp  Cloudflare      0.0     tr_max  60615  xfinity
# 469530       rtt     icmp  Cloudflare      0.0  tr_median  60615  xfinity
# 469531       rtt     icmp  Cloudflare      0.0     tr_min  60615  xfinity
#
#          value topic   annonipaddr  ipaddrchanged hour        date
# 0       37.488  beta  98.206.160.0              0   03  2021-10-16
# 1       40.056  beta  98.206.160.0              0   03  2021-10-16
# 2        1.094  beta  98.206.160.0              0   03  2021-10-16
# 3       36.042  beta  98.206.160.0              0   03  2021-10-16
# 4       12.619  beta  98.206.160.0              0   03  2021-10-16
# ...        ...   ...           ...            ...  ...         ...
# 469527   0.396  beta  98.206.160.0              0   06  2021-10-26
# 469528   8.436  beta  98.206.160.0              0   06  2021-10-26
# 469529   8.597  beta  98.206.160.0              0   06  2021-10-26
# 469530   8.589  beta  98.206.160.0              0   06  2021-10-26
# 469531   8.531  beta  98.206.160.0              0   06  2021-10-26
#
# [469532 rows x 16 columns]

# %%
#We are only looking at the target server Atlanta
#make a new dataframe with just atlanta target.
rc_device_atl = rc_device.loc[rc_device['target'] == 'Atlanta']
rc_device_atl
# Out:
#                        time                   deviceid          tool  \
# 0       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency
# 1       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency
# 2       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency
# 3       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency
# 77      2021-10-16 11:05:58  nm-mngd-20210518-075ab2f0  ping_latency
# ...                     ...                        ...           ...
# 469381  2021-10-26 11:26:01  nm-mngd-20210518-075ab2f0  ping_latency
# 469455  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  ping_latency
# 469456  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  ping_latency
# 469457  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  ping_latency
# 469458  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# 0            rtt     icmp  Atlanta      0.0    avg  60615  xfinity  37.488
# 1            rtt     icmp  Atlanta      0.0    max  60615  xfinity  40.056
# 2            rtt     icmp  Atlanta      0.0   mdev  60615  xfinity   1.094
# 3            rtt     icmp  Atlanta      0.0    min  60615  xfinity  36.042
# 77           rtt     icmp  Atlanta      0.0    avg  60615  xfinity  37.849
# ...          ...      ...      ...      ...    ...    ...      ...     ...
# 469381       rtt     icmp  Atlanta      0.0    min  60615  xfinity  36.837
# 469455       rtt     icmp  Atlanta      0.0    avg  60615  xfinity  36.785
# 469456       rtt     icmp  Atlanta      0.0    max  60615  xfinity  37.600
# 469457       rtt     icmp  Atlanta      0.0   mdev  60615  xfinity   0.544
# 469458       rtt     icmp  Atlanta      0.0    min  60615  xfinity  35.942
#
#        topic   annonipaddr  ipaddrchanged hour        date
# 0       beta  98.206.160.0              0   03  2021-10-16
# 1       beta  98.206.160.0              0   03  2021-10-16
# 2       beta  98.206.160.0              0   03  2021-10-16
# 3       beta  98.206.160.0              0   03  2021-10-16
# 77      beta  98.206.160.0              0   11  2021-10-16
# ...      ...           ...            ...  ...         ...
# 469381  beta  98.206.160.0              0   11  2021-10-26
# 469455  beta  98.206.160.0              0   06  2021-10-26
# 469456  beta  98.206.160.0              0   06  2021-10-26
# 469457  beta  98.206.160.0              0   06  2021-10-26
# 469458  beta  98.206.160.0              0   06  2021-10-26
#
# [24080 rows x 16 columns]

# %%
#make a dataframes for just the max, min, avg, and mdev
#This one is for the max
rc_device_atlmax= rc_device_atl.loc[rc_device_atl['method'] == 'max']
rc_device_atlmax
# Out:
#                        time                   deviceid          tool  \
# 1       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency
# 78      2021-10-16 11:05:58  nm-mngd-20210518-075ab2f0  ping_latency
# 155     2021-10-16 09:06:01  nm-mngd-20210518-075ab2f0  ping_latency
# 236     2021-10-16 07:10:59  nm-mngd-20210518-075ab2f0  ping_latency
# 313     2021-10-16 05:50:59  nm-mngd-20210518-075ab2f0  ping_latency
# ...                     ...                        ...           ...
# 469148  2021-10-26 12:00:58  nm-mngd-20210518-075ab2f0  ping_latency
# 469225  2021-10-26 12:10:57  nm-mngd-20210518-075ab2f0  ping_latency
# 469302  2021-10-26 04:06:01  nm-mngd-20210518-075ab2f0  ping_latency
# 469379  2021-10-26 11:26:01  nm-mngd-20210518-075ab2f0  ping_latency
# 469456  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# 1            rtt     icmp  Atlanta      0.0    max  60615  xfinity  40.056
# 78           rtt     icmp  Atlanta      0.0    max  60615  xfinity  42.617
# 155          rtt     icmp  Atlanta      0.0    max  60615  xfinity  39.620
# 236          rtt     icmp  Atlanta      0.0    max  60615  xfinity  39.826
# 313          rtt     icmp  Atlanta      0.0    max  60615  xfinity  39.339
# ...          ...      ...      ...      ...    ...    ...      ...     ...
# 469148       rtt     icmp  Atlanta      0.0    max  60615  xfinity  43.628
# 469225       rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.233
# 469302       rtt     icmp  Atlanta      0.0    max  60615  xfinity  42.979
# 469379       rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.386
# 469456       rtt     icmp  Atlanta      0.0    max  60615  xfinity  37.600
#
#        topic   annonipaddr  ipaddrchanged hour        date
# 1       beta  98.206.160.0              0   03  2021-10-16
# 78      beta  98.206.160.0              0   11  2021-10-16
# 155     beta  98.206.160.0              0   09  2021-10-16
# 236     beta  98.206.160.0              0   07  2021-10-16
# 313     beta  98.206.160.0              0   05  2021-10-16
# ...      ...           ...            ...  ...         ...
# 469148  beta  98.206.160.0              0   12  2021-10-26
# 469225  beta  98.206.160.0              0   12  2021-10-26
# 469302  beta  98.206.160.0              0   04  2021-10-26
# 469379  beta  98.206.160.0              0   11  2021-10-26
# 469456  beta  98.206.160.0              0   06  2021-10-26
#
# [6020 rows x 16 columns]

# %%
#This dataframe is for the min
rc_device_atlmin= rc_device_atl.loc[rc_device_atl['method'] == 'min']
rc_device_atlmin
# Out:
#                        time                   deviceid          tool  \
# 3       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency
# 80      2021-10-16 11:05:58  nm-mngd-20210518-075ab2f0  ping_latency
# 157     2021-10-16 09:06:01  nm-mngd-20210518-075ab2f0  ping_latency
# 238     2021-10-16 07:10:59  nm-mngd-20210518-075ab2f0  ping_latency
# 315     2021-10-16 05:50:59  nm-mngd-20210518-075ab2f0  ping_latency
# ...                     ...                        ...           ...
# 469150  2021-10-26 12:00:58  nm-mngd-20210518-075ab2f0  ping_latency
# 469227  2021-10-26 12:10:57  nm-mngd-20210518-075ab2f0  ping_latency
# 469304  2021-10-26 04:06:01  nm-mngd-20210518-075ab2f0  ping_latency
# 469381  2021-10-26 11:26:01  nm-mngd-20210518-075ab2f0  ping_latency
# 469458  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# 3            rtt     icmp  Atlanta      0.0    min  60615  xfinity  36.042
# 80           rtt     icmp  Atlanta      0.0    min  60615  xfinity  35.920
# 157          rtt     icmp  Atlanta      0.0    min  60615  xfinity  36.103
# 238          rtt     icmp  Atlanta      0.0    min  60615  xfinity  36.512
# 315          rtt     icmp  Atlanta      0.0    min  60615  xfinity  35.939
# ...          ...      ...      ...      ...    ...    ...      ...     ...
# 469150       rtt     icmp  Atlanta      0.0    min  60615  xfinity  36.362
# 469227       rtt     icmp  Atlanta      0.0    min  60615  xfinity  36.492
# 469304       rtt     icmp  Atlanta      0.0    min  60615  xfinity  36.151
# 469381       rtt     icmp  Atlanta      0.0    min  60615  xfinity  36.837
# 469458       rtt     icmp  Atlanta      0.0    min  60615  xfinity  35.942
#
#        topic   annonipaddr  ipaddrchanged hour        date
# 3       beta  98.206.160.0              0   03  2021-10-16
# 80      beta  98.206.160.0              0   11  2021-10-16
# 157     beta  98.206.160.0              0   09  2021-10-16
# 238     beta  98.206.160.0              0   07  2021-10-16
# 315     beta  98.206.160.0              0   05  2021-10-16
# ...      ...           ...            ...  ...         ...
# 469150  beta  98.206.160.0              0   12  2021-10-26
# 469227  beta  98.206.160.0              0   12  2021-10-26
# 469304  beta  98.206.160.0              0   04  2021-10-26
# 469381  beta  98.206.160.0              0   11  2021-10-26
# 469458  beta  98.206.160.0              0   06  2021-10-26
#
# [6020 rows x 16 columns]

# %%
#This dataframe is for the the avg 
rc_device_atlavg= rc_device_atl.loc[rc_device_atl['method'] == 'avg']
rc_device_atlavg
# Out:
#                        time                   deviceid          tool  \
# 0       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency
# 77      2021-10-16 11:05:58  nm-mngd-20210518-075ab2f0  ping_latency
# 154     2021-10-16 09:06:01  nm-mngd-20210518-075ab2f0  ping_latency
# 235     2021-10-16 07:10:59  nm-mngd-20210518-075ab2f0  ping_latency
# 312     2021-10-16 05:50:59  nm-mngd-20210518-075ab2f0  ping_latency
# ...                     ...                        ...           ...
# 469147  2021-10-26 12:00:58  nm-mngd-20210518-075ab2f0  ping_latency
# 469224  2021-10-26 12:10:57  nm-mngd-20210518-075ab2f0  ping_latency
# 469301  2021-10-26 04:06:01  nm-mngd-20210518-075ab2f0  ping_latency
# 469378  2021-10-26 11:26:01  nm-mngd-20210518-075ab2f0  ping_latency
# 469455  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# 0            rtt     icmp  Atlanta      0.0    avg  60615  xfinity  37.488
# 77           rtt     icmp  Atlanta      0.0    avg  60615  xfinity  37.849
# 154          rtt     icmp  Atlanta      0.0    avg  60615  xfinity  37.539
# 235          rtt     icmp  Atlanta      0.0    avg  60615  xfinity  37.598
# 312          rtt     icmp  Atlanta      0.0    avg  60615  xfinity  37.085
# ...          ...      ...      ...      ...    ...    ...      ...     ...
# 469147       rtt     icmp  Atlanta      0.0    avg  60615  xfinity  37.952
# 469224       rtt     icmp  Atlanta      0.0    avg  60615  xfinity  37.498
# 469301       rtt     icmp  Atlanta      0.0    avg  60615  xfinity  37.591
# 469378       rtt     icmp  Atlanta      0.0    avg  60615  xfinity  37.789
# 469455       rtt     icmp  Atlanta      0.0    avg  60615  xfinity  36.785
#
#        topic   annonipaddr  ipaddrchanged hour        date
# 0       beta  98.206.160.0              0   03  2021-10-16
# 77      beta  98.206.160.0              0   11  2021-10-16
# 154     beta  98.206.160.0              0   09  2021-10-16
# 235     beta  98.206.160.0              0   07  2021-10-16
# 312     beta  98.206.160.0              0   05  2021-10-16
# ...      ...           ...            ...  ...         ...
# 469147  beta  98.206.160.0              0   12  2021-10-26
# 469224  beta  98.206.160.0              0   12  2021-10-26
# 469301  beta  98.206.160.0              0   04  2021-10-26
# 469378  beta  98.206.160.0              0   11  2021-10-26
# 469455  beta  98.206.160.0              0   06  2021-10-26
#
# [6020 rows x 16 columns]

# %%
#This dataframe is for the mdev
rc_device_atlmdev= rc_device_atl.loc[rc_device_atl['method'] == 'mdev']
rc_device_atlmdev
# Out:
#                        time                   deviceid          tool  \
# 2       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency
# 79      2021-10-16 11:05:58  nm-mngd-20210518-075ab2f0  ping_latency
# 156     2021-10-16 09:06:01  nm-mngd-20210518-075ab2f0  ping_latency
# 237     2021-10-16 07:10:59  nm-mngd-20210518-075ab2f0  ping_latency
# 314     2021-10-16 05:50:59  nm-mngd-20210518-075ab2f0  ping_latency
# ...                     ...                        ...           ...
# 469149  2021-10-26 12:00:58  nm-mngd-20210518-075ab2f0  ping_latency
# 469226  2021-10-26 12:10:57  nm-mngd-20210518-075ab2f0  ping_latency
# 469303  2021-10-26 04:06:01  nm-mngd-20210518-075ab2f0  ping_latency
# 469380  2021-10-26 11:26:01  nm-mngd-20210518-075ab2f0  ping_latency
# 469457  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp  value  \
# 2            rtt     icmp  Atlanta      0.0   mdev  60615  xfinity  1.094
# 79           rtt     icmp  Atlanta      0.0   mdev  60615  xfinity  2.163
# 156          rtt     icmp  Atlanta      0.0   mdev  60615  xfinity  0.921
# 237          rtt     icmp  Atlanta      0.0   mdev  60615  xfinity  0.964
# 314          rtt     icmp  Atlanta      0.0   mdev  60615  xfinity  1.037
# ...          ...      ...      ...      ...    ...    ...      ...    ...
# 469149       rtt     icmp  Atlanta      0.0   mdev  60615  xfinity  2.015
# 469226       rtt     icmp  Atlanta      0.0   mdev  60615  xfinity  0.578
# 469303       rtt     icmp  Atlanta      0.0   mdev  60615  xfinity  1.909
# 469380       rtt     icmp  Atlanta      0.0   mdev  60615  xfinity  0.536
# 469457       rtt     icmp  Atlanta      0.0   mdev  60615  xfinity  0.544
#
#        topic   annonipaddr  ipaddrchanged hour        date
# 2       beta  98.206.160.0              0   03  2021-10-16
# 79      beta  98.206.160.0              0   11  2021-10-16
# 156     beta  98.206.160.0              0   09  2021-10-16
# 237     beta  98.206.160.0              0   07  2021-10-16
# 314     beta  98.206.160.0              0   05  2021-10-16
# ...      ...           ...            ...  ...         ...
# 469149  beta  98.206.160.0              0   12  2021-10-26
# 469226  beta  98.206.160.0              0   12  2021-10-26
# 469303  beta  98.206.160.0              0   04  2021-10-26
# 469380  beta  98.206.160.0              0   11  2021-10-26
# 469457  beta  98.206.160.0              0   06  2021-10-26
#
# [6020 rows x 16 columns]

# %%
#Todays objective require me to work with the max data from the device which i already make a dataframe for called 'rc_device_atlmax'
#I am going to change the column hour into intengers making it easier to work with later on.
#then will print the dtypes to corfirm if it changed.
rc_device_atlmax.hour = rc_device_atlmax['hour'].astype('int')
print(rc_device_atlmax.dtypes)
# Out:
# time              object
# deviceid          object
# tool              object
# direction         object
# protocol          object
# target            object
# pktloss          float64
# method            object
# zip                int64
# isp               object
# value            float64
# topic             object
# annonipaddr       object
# ipaddrchanged      int64
# hour               int64
# date              object
# dtype: object
# /tmp/ipykernel_1312869/148648071.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rc_device_atlmax.hour = rc_device_atlmax['hour'].astype('int')

# %%
#One object today was to look at 7 days from the dataframe.
#Make a random sample of seven days from the atlanta max dataframe rc_device_atlmax
rc_device_atlmax['date'].sample(7, replace=False)
# Out:
# 467189    2021-10-26
# 153230    2021-10-27
# 104279    2021-10-23
# 37568     2021-10-24
# 381684    2021-10-18
# 449988    2021-10-26
# 305855    2021-10-17
# Name: date, dtype: object

# %%
#Now we have the random sample of seven dates to use. 
#Make a subset for each day, make sure your making using the dataframe rc_device_atlmax
#This one is for the day 10-19
rc_device_atlmax_1019 = rc_device_atlmax.loc[rc_device_atlmax['date'] == '2021-10-19']
rc_device_atlmax_1019
# Out:
#                        time                   deviceid          tool  \
# 184562  2021-10-19 23:10:59  nm-mngd-20210518-075ab2f0  ping_latency
# 185105  2021-10-19 21:45:58  nm-mngd-20210518-075ab2f0  ping_latency
# 185182  2021-10-19 22:20:58  nm-mngd-20210518-075ab2f0  ping_latency
# 185879  2021-10-19 20:05:58  nm-mngd-20210518-075ab2f0  ping_latency
# 186187  2021-10-19 20:45:58  nm-mngd-20210518-075ab2f0  ping_latency
# ...                     ...                        ...           ...
# 394618  2021-10-19 08:35:58  nm-mngd-20210518-075ab2f0  ping_latency
# 394772  2021-10-19 00:25:58  nm-mngd-20210518-075ab2f0  ping_latency
# 394853  2021-10-19 11:45:59  nm-mngd-20210518-075ab2f0  ping_latency
# 394930  2021-10-19 12:11:00  nm-mngd-20210518-075ab2f0  ping_latency
# 395007  2021-10-19 02:26:01  nm-mngd-20210518-075ab2f0  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# 184562       rtt     icmp  Atlanta      0.0    max  60615  xfinity  47.470
# 185105       rtt     icmp  Atlanta      0.0    max  60615  xfinity  44.517
# 185182       rtt     icmp  Atlanta      0.0    max  60615  xfinity  54.113
# 185879       rtt     icmp  Atlanta      0.0    max  60615  xfinity  42.322
# 186187       rtt     icmp  Atlanta      0.0    max  60615  xfinity  48.488
# ...          ...      ...      ...      ...    ...    ...      ...     ...
# 394618       rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.775
# 394772       rtt     icmp  Atlanta      0.0    max  60615  xfinity  42.658
# 394853       rtt     icmp  Atlanta      0.0    max  60615  xfinity  41.247
# 394930       rtt     icmp  Atlanta      0.0    max  60615  xfinity  43.703
# 395007       rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.326
#
#        topic   annonipaddr  ipaddrchanged  hour        date
# 184562  beta  98.206.160.0              0    23  2021-10-19
# 185105  beta  98.206.160.0              0    21  2021-10-19
# 185182  beta  98.206.160.0              0    22  2021-10-19
# 185879  beta  98.206.160.0              0    20  2021-10-19
# 186187  beta  98.206.160.0              0    20  2021-10-19
# ...      ...           ...            ...   ...         ...
# 394618  beta  98.206.160.0              0     8  2021-10-19
# 394772  beta  98.206.160.0              0     0  2021-10-19
# 394853  beta  98.206.160.0              0    11  2021-10-19
# 394930  beta  98.206.160.0              0    12  2021-10-19
# 395007  beta  98.206.160.0              0     2  2021-10-19
#
# [288 rows x 16 columns]

# %%
#This subset is for 10/12
rc_device_atlmax_1012 = rc_device_atlmax.loc[rc_device_atlmax['date'] == '2021-10-12']
rc_device_atlmax_1012
# Out:
#                        time                   deviceid          tool  \
# 206857  2021-10-12 01:25:58  nm-mngd-20210518-075ab2f0  ping_latency
# 207088  2021-10-12 10:45:59  nm-mngd-20210518-075ab2f0  ping_latency
# 207165  2021-10-12 09:20:59  nm-mngd-20210518-075ab2f0  ping_latency
# 207327  2021-10-12 15:10:58  nm-mngd-20210518-075ab2f0  ping_latency
# 207404  2021-10-12 12:21:07  nm-mngd-20210518-075ab2f0  ping_latency
# ...                     ...                        ...           ...
# 415403  2021-10-12 23:10:59  nm-mngd-20210518-075ab2f0  ping_latency
# 416029  2021-10-12 21:20:58  nm-mngd-20210518-075ab2f0  ping_latency
# 416418  2021-10-12 20:05:58  nm-mngd-20210518-075ab2f0  ping_latency
# 416649  2021-10-12 23:35:59  nm-mngd-20210518-075ab2f0  ping_latency
# 417283  2021-10-12 21:05:58  nm-mngd-20210518-075ab2f0  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# 206857       rtt     icmp  Atlanta      0.0    max  60615  xfinity  37.954
# 207088       rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.603
# 207165       rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.653
# 207327       rtt     icmp  Atlanta      0.0    max  60615  xfinity  41.910
# 207404       rtt     icmp  Atlanta      0.0    max  60615  xfinity  49.661
# ...          ...      ...      ...      ...    ...    ...      ...     ...
# 415403       rtt     icmp  Atlanta      0.0    max  60615  xfinity  48.784
# 416029       rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.980
# 416418       rtt     icmp  Atlanta      0.0    max  60615  xfinity  41.489
# 416649       rtt     icmp  Atlanta      0.0    max  60615  xfinity  46.582
# 417283       rtt     icmp  Atlanta      0.0    max  60615  xfinity  39.309
#
#        topic   annonipaddr  ipaddrchanged  hour        date
# 206857  beta  98.206.160.0              0     1  2021-10-12
# 207088  beta  98.206.160.0              0    10  2021-10-12
# 207165  beta  98.206.160.0              0     9  2021-10-12
# 207327  beta  98.206.160.0              0    15  2021-10-12
# 207404  beta  98.206.160.0              0    12  2021-10-12
# ...      ...           ...            ...   ...         ...
# 415403  beta  98.206.160.0              0    23  2021-10-12
# 416029  beta  98.206.160.0              0    21  2021-10-12
# 416418  beta  98.206.160.0              0    20  2021-10-12
# 416649  beta  98.206.160.0              0    23  2021-10-12
# 417283  beta  98.206.160.0              0    21  2021-10-12
#
# [269 rows x 16 columns]

# %%
#This subset is for 10/15
rc_device_atlmax_1015 = rc_device_atlmax.loc[rc_device_atlmax['date'] == '2021-10-15']
rc_device_atlmax_1015
# Out:
#                        time                   deviceid          tool  \
# 1087    2021-10-15 21:30:58  nm-mngd-20210518-075ab2f0  ping_latency
# 1168    2021-10-15 22:55:58  nm-mngd-20210518-075ab2f0  ping_latency
# 1245    2021-10-15 20:15:58  nm-mngd-20210518-075ab2f0  ping_latency
# 1634    2021-10-15 19:30:58  nm-mngd-20210518-075ab2f0  ping_latency
# 1711    2021-10-15 20:55:58  nm-mngd-20210518-075ab2f0  ping_latency
# ...                     ...                        ...           ...
# 138705  2021-10-15 07:35:59  nm-mngd-20210518-075ab2f0  ping_latency
# 138859  2021-10-15 11:20:58  nm-mngd-20210518-075ab2f0  ping_latency
# 138944  2021-10-15 02:31:00  nm-mngd-20210518-075ab2f0  ping_latency
# 139021  2021-10-15 14:45:59  nm-mngd-20210518-075ab2f0  ping_latency
# 139098  2021-10-15 02:00:59  nm-mngd-20210518-075ab2f0  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# 1087         rtt     icmp  Atlanta      0.0    max  60615  xfinity  42.061
# 1168         rtt     icmp  Atlanta      0.0    max  60615  xfinity  39.691
# 1245         rtt     icmp  Atlanta      0.0    max  60615  xfinity  44.198
# 1634         rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.650
# 1711         rtt     icmp  Atlanta      0.0    max  60615  xfinity  43.142
# ...          ...      ...      ...      ...    ...    ...      ...     ...
# 138705       rtt     icmp  Atlanta      0.0    max  60615  xfinity  39.819
# 138859       rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.801
# 138944       rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.288
# 139021       rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.356
# 139098       rtt     icmp  Atlanta      0.0    max  60615  xfinity  39.163
#
#        topic   annonipaddr  ipaddrchanged  hour        date
# 1087    beta  98.206.160.0              0    21  2021-10-15
# 1168    beta  98.206.160.0              0    22  2021-10-15
# 1245    beta  98.206.160.0              0    20  2021-10-15
# 1634    beta  98.206.160.0              0    19  2021-10-15
# 1711    beta  98.206.160.0              0    20  2021-10-15
# ...      ...           ...            ...   ...         ...
# 138705  beta  98.206.160.0              0     7  2021-10-15
# 138859  beta  98.206.160.0              0    11  2021-10-15
# 138944  beta  98.206.160.0              0     2  2021-10-15
# 139021  beta  98.206.160.0              0    14  2021-10-15
# 139098  beta  98.206.160.0              0     2  2021-10-15
#
# [288 rows x 16 columns]

# %%
#This subset is for 10/21
rc_device_atlmax_1021 = rc_device_atlmax.loc[rc_device_atlmax['date'] == '2021-10-21']
rc_device_atlmax_1021
# Out:
#                        time                   deviceid          tool  \
# 250616  2021-10-21 22:35:59  nm-mngd-20210518-075ab2f0  ping_latency
# 250697  2021-10-21 23:05:58  nm-mngd-20210518-075ab2f0  ping_latency
# 250851  2021-10-21 20:21:00  nm-mngd-20210518-075ab2f0  ping_latency
# 251477  2021-10-21 19:36:00  nm-mngd-20210518-075ab2f0  ping_latency
# 251554  2021-10-21 21:35:59  nm-mngd-20210518-075ab2f0  ping_latency
# ...                     ...                        ...           ...
# 372376  2021-10-21 11:40:58  nm-mngd-20210518-075ab2f0  ping_latency
# 372453  2021-10-21 15:30:59  nm-mngd-20210518-075ab2f0  ping_latency
# 372530  2021-10-21 18:15:59  nm-mngd-20210518-075ab2f0  ping_latency
# 372607  2021-10-21 05:15:59  nm-mngd-20210518-075ab2f0  ping_latency
# 372688  2021-10-21 16:16:00  nm-mngd-20210518-075ab2f0  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# 250616       rtt     icmp  Atlanta      0.0    max  60615  xfinity  40.550
# 250697       rtt     icmp  Atlanta      0.0    max  60615  xfinity  47.353
# 250851       rtt     icmp  Atlanta      0.0    max  60615  xfinity  44.464
# 251477       rtt     icmp  Atlanta      0.0    max  60615  xfinity  42.263
# 251554       rtt     icmp  Atlanta      0.0    max  60615  xfinity  49.561
# ...          ...      ...      ...      ...    ...    ...      ...     ...
# 372376       rtt     icmp  Atlanta      0.0    max  60615  xfinity  39.116
# 372453       rtt     icmp  Atlanta      0.0    max  60615  xfinity  42.280
# 372530       rtt     icmp  Atlanta      0.0    max  60615  xfinity  40.175
# 372607       rtt     icmp  Atlanta      0.0    max  60615  xfinity  46.036
# 372688       rtt     icmp  Atlanta      0.0    max  60615  xfinity  40.005
#
#        topic   annonipaddr  ipaddrchanged  hour        date
# 250616  beta  98.206.160.0              0    22  2021-10-21
# 250697  beta  98.206.160.0              0    23  2021-10-21
# 250851  beta  98.206.160.0              0    20  2021-10-21
# 251477  beta  98.206.160.0              0    19  2021-10-21
# 251554  beta  98.206.160.0              0    21  2021-10-21
# ...      ...           ...            ...   ...         ...
# 372376  beta  98.206.160.0              0    11  2021-10-21
# 372453  beta  98.206.160.0              0    15  2021-10-21
# 372530  beta  98.206.160.0              0    18  2021-10-21
# 372607  beta  98.206.160.0              0     5  2021-10-21
# 372688  beta  98.206.160.0              0    16  2021-10-21
#
# [288 rows x 16 columns]

# %%
#This subset is for 10/01
#From breaking the dataframe into subsets from different days , I could now see that the date 10/01 has missing data.
#This subset outputed 78 rows while the other days from the random sample have 288 rows as excepted.
rc_device_atlmax_1001 = rc_device_atlmax.loc[rc_device_atlmax['date'] == '2021-10-01']
rc_device_atlmax_1001
# Out:
#                        time                   deviceid          tool  \
# 289976  2021-10-01 17:51:00  nm-mngd-20210518-075ab2f0  ping_latency
# 290053  2021-10-01 18:05:59  nm-mngd-20210518-075ab2f0  ping_latency
# 290130  2021-10-01 19:05:58  nm-mngd-20210518-075ab2f0  ping_latency
# 290207  2021-10-01 20:51:01  nm-mngd-20210518-075ab2f0  ping_latency
# 290284  2021-10-01 21:45:58  nm-mngd-20210518-075ab2f0  ping_latency
# ...                     ...                        ...           ...
# 303523  2021-10-01 22:01:00  nm-mngd-20210518-075ab2f0  ping_latency
# 303754  2021-10-01 21:16:00  nm-mngd-20210518-075ab2f0  ping_latency
# 303831  2021-10-01 20:15:59  nm-mngd-20210518-075ab2f0  ping_latency
# 304299  2021-10-01 22:15:59  nm-mngd-20210518-075ab2f0  ping_latency
# 304858  2021-10-01 18:30:58  nm-mngd-20210518-075ab2f0  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# 289976       rtt     icmp  Atlanta      0.0    max  60615  xfinity  42.366
# 290053       rtt     icmp  Atlanta      0.0    max  60615  xfinity  41.493
# 290130       rtt     icmp  Atlanta      0.0    max  60615  xfinity  42.628
# 290207       rtt     icmp  Atlanta      0.0    max  60615  xfinity  41.072
# 290284       rtt     icmp  Atlanta      0.0    max  60615  xfinity  37.206
# ...          ...      ...      ...      ...    ...    ...      ...     ...
# 303523       rtt     icmp  Atlanta      0.0    max  60615  xfinity  37.543
# 303754       rtt     icmp  Atlanta      0.0    max  60615  xfinity  39.031
# 303831       rtt     icmp  Atlanta      0.0    max  60615  xfinity  40.395
# 304299       rtt     icmp  Atlanta      0.0    max  60615  xfinity  37.095
# 304858       rtt     icmp  Atlanta      0.0    max  60615  xfinity  40.576
#
#        topic   annonipaddr  ipaddrchanged  hour        date
# 289976  beta  98.206.160.0              0    17  2021-10-01
# 290053  beta  98.206.160.0              0    18  2021-10-01
# 290130  beta  98.206.160.0              0    19  2021-10-01
# 290207  beta  98.206.160.0              0    20  2021-10-01
# 290284  beta  98.206.160.0              0    21  2021-10-01
# ...      ...           ...            ...   ...         ...
# 303523  beta  98.206.160.0              0    22  2021-10-01
# 303754  beta  98.206.160.0              0    21  2021-10-01
# 303831  beta  98.206.160.0              0    20  2021-10-01
# 304299  beta  98.206.160.0              0    22  2021-10-01
# 304858  beta  98.206.160.0              0    18  2021-10-01
#
# [76 rows x 16 columns]

# %%
#This subset is should be 10/21 based on the random sample code however being that I already have a subset of that day and the objective was to look at 7 different days Im going to chose a random day to eliminate doing a duplicate day.
#The new date picked is 10/07
rc_device_atlmax_1007 = rc_device_atlmax.loc[rc_device_atlmax['date'] == '2021-10-07']
rc_device_atlmax_1007
# Out:
#                        time                   deviceid          tool  \
# 67487   2021-10-07 21:55:58  nm-mngd-20210518-075ab2f0  ping_latency
# 68741   2021-10-07 20:55:58  nm-mngd-20210518-075ab2f0  ping_latency
# 69053   2021-10-07 19:30:58  nm-mngd-20210518-075ab2f0  ping_latency
# 69361   2021-10-07 19:55:58  nm-mngd-20210518-075ab2f0  ping_latency
# 69438   2021-10-07 20:30:58  nm-mngd-20210518-075ab2f0  ping_latency
# ...                     ...                        ...           ...
# 439390  2021-10-07 10:40:58  nm-mngd-20210518-075ab2f0  ping_latency
# 439548  2021-10-07 17:30:59  nm-mngd-20210518-075ab2f0  ping_latency
# 439625  2021-10-07 03:06:01  nm-mngd-20210518-075ab2f0  ping_latency
# 439712  2021-10-07 18:55:59  nm-mngd-20210518-075ab2f0  ping_latency
# 439789  2021-10-07 09:40:58  nm-mngd-20210518-075ab2f0  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# 67487        rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.052
# 68741        rtt     icmp  Atlanta      0.0    max  60615  xfinity  43.114
# 69053        rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.372
# 69361        rtt     icmp  Atlanta      0.0    max  60615  xfinity  43.333
# 69438        rtt     icmp  Atlanta      0.0    max  60615  xfinity  42.150
# ...          ...      ...      ...      ...    ...    ...      ...     ...
# 439390       rtt     icmp  Atlanta      0.0    max  60615  xfinity  39.176
# 439548       rtt     icmp  Atlanta      0.0    max  60615  xfinity  41.202
# 439625       rtt     icmp  Atlanta      0.0    max  60615  xfinity  39.174
# 439712       rtt     icmp  Atlanta      0.0    max  60615  xfinity  41.507
# 439789       rtt     icmp  Atlanta      0.0    max  60615  xfinity  41.734
#
#        topic   annonipaddr  ipaddrchanged  hour        date
# 67487   beta  98.206.160.0              0    21  2021-10-07
# 68741   beta  98.206.160.0              0    20  2021-10-07
# 69053   beta  98.206.160.0              0    19  2021-10-07
# 69361   beta  98.206.160.0              0    19  2021-10-07
# 69438   beta  98.206.160.0              0    20  2021-10-07
# ...      ...           ...            ...   ...         ...
# 439390  beta  98.206.160.0              0    10  2021-10-07
# 439548  beta  98.206.160.0              0    17  2021-10-07
# 439625  beta  98.206.160.0              0     3  2021-10-07
# 439712  beta  98.206.160.0              0    18  2021-10-07
# 439789  beta  98.206.160.0              0     9  2021-10-07
#
# [288 rows x 16 columns]

# %%
#This subset is for 10/17
rc_device_atlmax_1017 = rc_device_atlmax.loc[rc_device_atlmax['date'] == '2021-10-17']
rc_device_atlmax_1017
# Out:
#                        time                   deviceid          tool  \
# 227801  2021-10-17 22:40:58  nm-mngd-20210518-075ab2f0  ping_latency
# 227959  2021-10-17 21:25:58  nm-mngd-20210518-075ab2f0  ping_latency
# 229284  2021-10-17 22:00:58  nm-mngd-20210518-075ab2f0  ping_latency
# 229361  2021-10-17 20:40:58  nm-mngd-20210518-075ab2f0  ping_latency
# 229515  2021-10-17 23:50:57  nm-mngd-20210518-075ab2f0  ping_latency
# ...                     ...                        ...           ...
# 327428  2021-10-17 06:55:58  nm-mngd-20210518-075ab2f0  ping_latency
# 327505  2021-10-17 05:20:57  nm-mngd-20210518-075ab2f0  ping_latency
# 327582  2021-10-17 05:30:58  nm-mngd-20210518-075ab2f0  ping_latency
# 327659  2021-10-17 01:30:57  nm-mngd-20210518-075ab2f0  ping_latency
# 327736  2021-10-17 18:30:58  nm-mngd-20210518-075ab2f0  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# 227801       rtt     icmp  Atlanta      0.0    max  60615  xfinity  41.671
# 227959       rtt     icmp  Atlanta      0.0    max  60615  xfinity  40.016
# 229284       rtt     icmp  Atlanta      0.0    max  60615  xfinity  42.497
# 229361       rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.771
# 229515       rtt     icmp  Atlanta      0.0    max  60615  xfinity  45.511
# ...          ...      ...      ...      ...    ...    ...      ...     ...
# 327428       rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.666
# 327505       rtt     icmp  Atlanta      0.0    max  60615  xfinity  40.250
# 327582       rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.259
# 327659       rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.395
# 327736       rtt     icmp  Atlanta      0.0    max  60615  xfinity  42.368
#
#        topic   annonipaddr  ipaddrchanged  hour        date
# 227801  beta  98.206.160.0              0    22  2021-10-17
# 227959  beta  98.206.160.0              0    21  2021-10-17
# 229284  beta  98.206.160.0              0    22  2021-10-17
# 229361  beta  98.206.160.0              0    20  2021-10-17
# 229515  beta  98.206.160.0              0    23  2021-10-17
# ...      ...           ...            ...   ...         ...
# 327428  beta  98.206.160.0              0     6  2021-10-17
# 327505  beta  98.206.160.0              0     5  2021-10-17
# 327582  beta  98.206.160.0              0     5  2021-10-17
# 327659  beta  98.206.160.0              0     1  2021-10-17
# 327736  beta  98.206.160.0              0    18  2021-10-17
#
# [288 rows x 16 columns]

# %%
#Time series plot of the maxes from the date 10/19 (from the one device)
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.lineplot( x = "time", y = "value",
             color = 'green', data =rc_device_atlmax_1019,)
plt.tick_params(labelrotation = 25)
plt.xticks(np.arange(1,288,24))
# Out:
# ([<matplotlib.axis.XTick at 0x7f3dc0a71b20>,
#   <matplotlib.axis.XTick at 0x7f3dc0a71af0>,
#   <matplotlib.axis.XTick at 0x7f3dc0b54940>,
#   <matplotlib.axis.XTick at 0x7f3dc099cdc0>,
#   <matplotlib.axis.XTick at 0x7f3dc0932940>,
#   <matplotlib.axis.XTick at 0x7f3dc0945430>,
#   <matplotlib.axis.XTick at 0x7f3dc0945ee0>,
#   <matplotlib.axis.XTick at 0x7f3dc09499d0>,
#   <matplotlib.axis.XTick at 0x7f3dc0949190>,
#   <matplotlib.axis.XTick at 0x7f3dc09c7a60>,
#   <matplotlib.axis.XTick at 0x7f3dc094fca0>,
#   <matplotlib.axis.XTick at 0x7f3dc0957790>],
#  [Text(1, 0, '2021-10-19 21:45:58'),
#   Text(25, 0, '2021-10-19 21:35:58'),
#   Text(49, 0, '2021-10-19 21:00:58'),
#   Text(73, 0, '2021-10-19 02:10:59'),
#   Text(97, 0, '2021-10-19 17:41:01'),
#   Text(121, 0, '2021-10-19 17:25:58'),
#   Text(145, 0, '2021-10-19 13:30:58'),
#   Text(169, 0, '2021-10-19 11:00:58'),
#   Text(193, 0, '2021-10-19 15:05:58'),
#   Text(217, 0, '2021-10-19 12:20:58'),
#   Text(241, 0, '2021-10-19 00:30:59'),
#   Text(265, 0, '2021-10-19 14:05:58')])

# %%
#Time series plot of the maxes from the date 10/12 (from the one device)
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


sns.lineplot( x = "time", y = "value",
             color = 'red', data =rc_device_atlmax_1012,)
plt.tick_params(labelrotation = 25)
plt.xticks(np.arange(1,288,24))
# Out:
# ([<matplotlib.axis.XTick at 0x7f3dc06a5f40>,
#   <matplotlib.axis.XTick at 0x7f3dc06a5e20>,
#   <matplotlib.axis.XTick at 0x7f3dbe5791c0>,
#   <matplotlib.axis.XTick at 0x7f3dbcd33df0>,
#   <matplotlib.axis.XTick at 0x7f3dbcd568e0>,
#   <matplotlib.axis.XTick at 0x7f3dbcd56df0>,
#   <matplotlib.axis.XTick at 0x7f3dbcd5b8e0>,
#   <matplotlib.axis.XTick at 0x7f3dbcd5d3d0>,
#   <matplotlib.axis.XTick at 0x7f3dbcd5de80>,
#   <matplotlib.axis.XTick at 0x7f3dbcd5d910>,
#   <matplotlib.axis.XTick at 0x7f3dbcd5b280>,
#   <matplotlib.axis.XTick at 0x7f3dbccef2b0>],
#  [Text(1, 0, '2021-10-12 10:45:59'),
#   Text(25, 0, '2021-10-12 06:00:57'),
#   Text(49, 0, '2021-10-12 16:05:59'),
#   Text(73, 0, '2021-10-12 15:50:59'),
#   Text(97, 0, '2021-10-12 05:45:58'),
#   Text(121, 0, '2021-10-12 07:15:59'),
#   Text(145, 0, '2021-10-12 09:41:00'),
#   Text(169, 0, '2021-10-12 07:30:58'),
#   Text(193, 0, '2021-10-12 13:15:59'),
#   Text(217, 0, '2021-10-12 22:55:59'),
#   Text(241, 0, '2021-10-12 19:35:58'),
#   Text(265, 0, '2021-10-12 21:20:58')])

# %%
#Time series plot of the maxes from the date 10/15 (from the one device)
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.lineplot( x = "time", y = "value",
             color = 'black', data =rc_device_atlmax_1015,)
plt.tick_params(labelrotation = 25)
plt.xticks(np.arange(1,288,24))
# Out:
# ([<matplotlib.axis.XTick at 0x7f3dbc9b40d0>,
#   <matplotlib.axis.XTick at 0x7f3dbc9b40a0>,
#   <matplotlib.axis.XTick at 0x7f3dbca21220>,
#   <matplotlib.axis.XTick at 0x7f3dbc9e3d90>,
#   <matplotlib.axis.XTick at 0x7f3dc0a47fd0>,
#   <matplotlib.axis.XTick at 0x7f3dc0945eb0>,
#   <matplotlib.axis.XTick at 0x7f3dc0932760>,
#   <matplotlib.axis.XTick at 0x7f3dc09629a0>,
#   <matplotlib.axis.XTick at 0x7f3dc08feb50>,
#   <matplotlib.axis.XTick at 0x7f3dc091a460>,
#   <matplotlib.axis.XTick at 0x7f3dc08f4b50>,
#   <matplotlib.axis.XTick at 0x7f3dc090c520>],
#  [Text(1, 0, '2021-10-15 22:55:58'),
#   Text(25, 0, '2021-10-15 20:40:58'),
#   Text(49, 0, '2021-10-15 22:05:58'),
#   Text(73, 0, '2021-10-15 07:31:01'),
#   Text(97, 0, '2021-10-15 18:41:00'),
#   Text(121, 0, '2021-10-15 09:55:58'),
#   Text(145, 0, '2021-10-15 08:55:58'),
#   Text(169, 0, '2021-10-15 18:30:58'),
#   Text(193, 0, '2021-10-15 09:50:58'),
#   Text(217, 0, '2021-10-15 04:25:59'),
#   Text(241, 0, '2021-10-15 14:20:58'),
#   Text(265, 0, '2021-10-15 14:05:59')])

# %%
#Time series plot of the maxes from the date 10/21 (from the one device)
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.lineplot( x = "time", y = "value",
             color = 'purple', data =rc_device_atlmax_1021,)
plt.tick_params(labelrotation = 25)
plt.xticks(np.arange(1,288,24))
# Out:
# ([<matplotlib.axis.XTick at 0x7f3dbc60c100>,
#   <matplotlib.axis.XTick at 0x7f3dbc60c0d0>,
#   <matplotlib.axis.XTick at 0x7f3dbe579eb0>,
#   <matplotlib.axis.XTick at 0x7f3dbc5b99d0>,
#   <matplotlib.axis.XTick at 0x7f3dbc5d54c0>,
#   <matplotlib.axis.XTick at 0x7f3dbc5d5f70>,
#   <matplotlib.axis.XTick at 0x7f3dbc5d9a60>,
#   <matplotlib.axis.XTick at 0x7f3dbc5b9520>,
#   <matplotlib.axis.XTick at 0x7f3dbc5e14c0>,
#   <matplotlib.axis.XTick at 0x7f3dbc5e1f70>,
#   <matplotlib.axis.XTick at 0x7f3dbc5e6a60>,
#   <matplotlib.axis.XTick at 0x7f3dbc56b550>],
#  [Text(1, 0, '2021-10-21 23:05:58'),
#   Text(25, 0, '2021-10-21 20:51:00'),
#   Text(49, 0, '2021-10-21 21:26:00'),
#   Text(73, 0, '2021-10-21 12:50:59'),
#   Text(97, 0, '2021-10-21 16:21:00'),
#   Text(121, 0, '2021-10-21 08:51:00'),
#   Text(145, 0, '2021-10-21 18:10:58'),
#   Text(169, 0, '2021-10-21 13:05:58'),
#   Text(193, 0, '2021-10-21 14:56:00'),
#   Text(217, 0, '2021-10-21 01:05:58'),
#   Text(241, 0, '2021-10-21 09:15:59'),
#   Text(265, 0, '2021-10-21 12:00:58')])

# %%
#Time series plot of the maxes from the date 10/01 (from the one device)
#This series plot will look different than the rest of them because there was missing data. Once I made a dataframe for just this date there was only 78 rows instead of the intended 288.
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.lineplot( x = "time", y = "value",
             color = 'yellow', data =rc_device_atlmax_1001,)
plt.tick_params(labelrotation = 25)
plt.xticks(np.arange(1,76, 12))
# Out:
# ([<matplotlib.axis.XTick at 0x7f3dbc294250>,
#   <matplotlib.axis.XTick at 0x7f3dbc294220>,
#   <matplotlib.axis.XTick at 0x7f3dbc2622b0>,
#   <matplotlib.axis.XTick at 0x7f3dbc224c70>,
#   <matplotlib.axis.XTick at 0x7f3dbc1ab760>,
#   <matplotlib.axis.XTick at 0x7f3dbc1b3250>,
#   <matplotlib.axis.XTick at 0x7f3dbc1b3d00>],
#  [Text(1, 0, '2021-10-01 18:05:59'),
#   Text(13, 0, '2021-10-01 21:05:58'),
#   Text(25, 0, '2021-10-01 22:11:00'),
#   Text(37, 0, '2021-10-01 18:10:59'),
#   Text(49, 0, '2021-10-01 19:15:58'),
#   Text(61, 0, '2021-10-01 17:25:59'),
#   Text(73, 0, '2021-10-01 20:15:59')])

# %%
#Time series plot of the maxes from the date 10/07 (from the one device) 
#remember that the random sample gave us two dates that were the same so we picked a different date for one of them which is 10/07
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.lineplot( x = "time", y = "value",
             color = 'brown', data =rc_device_atlmax_1007,)
plt.tick_params(labelrotation = 25)
plt.xticks(np.arange(1,288,24))
# Out:
# ([<matplotlib.axis.XTick at 0x7f3dbc181580>,
#   <matplotlib.axis.XTick at 0x7f3dbc1815e0>,
#   <matplotlib.axis.XTick at 0x7f3dbc1c4e50>,
#   <matplotlib.axis.XTick at 0x7f3dbca21070>,
#   <matplotlib.axis.XTick at 0x7f3dbc13bdf0>,
#   <matplotlib.axis.XTick at 0x7f3dbc06b8e0>,
#   <matplotlib.axis.XTick at 0x7f3dbc0713d0>,
#   <matplotlib.axis.XTick at 0x7f3dbc06b190>,
#   <matplotlib.axis.XTick at 0x7f3dbc071df0>,
#   <matplotlib.axis.XTick at 0x7f3dbc0778e0>,
#   <matplotlib.axis.XTick at 0x7f3dbc07c3d0>,
#   <matplotlib.axis.XTick at 0x7f3dbc07ce80>],
#  [Text(1, 0, '2021-10-07 20:55:58'),
#   Text(25, 0, '2021-10-07 21:40:58'),
#   Text(49, 0, '2021-10-07 22:35:58'),
#   Text(73, 0, '2021-10-07 14:10:58'),
#   Text(97, 0, '2021-10-07 05:10:59'),
#   Text(121, 0, '2021-10-07 11:50:58'),
#   Text(145, 0, '2021-10-07 01:30:59'),
#   Text(169, 0, '2021-10-07 15:35:58'),
#   Text(193, 0, '2021-10-07 13:01:00'),
#   Text(217, 0, '2021-10-07 08:41:01'),
#   Text(241, 0, '2021-10-07 03:50:59'),
#   Text(265, 0, '2021-10-07 01:05:59')])

# %%
#Time series plot of the maxes from the date 10/17 (from the one device) 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.lineplot(x = "time", y = "value",
             color = 'orange', data =rc_device_atlmax_1017,)
plt.tick_params(labelrotation = 25)
plt.xticks(np.arange(1,288,24))
# Out:
# ([<matplotlib.axis.XTick at 0x7f3db7ce3a90>,
#   <matplotlib.axis.XTick at 0x7f3db7ce3a60>,
#   <matplotlib.axis.XTick at 0x7f3dbc137490>,
#   <matplotlib.axis.XTick at 0x7f3db7c98dc0>,
#   <matplotlib.axis.XTick at 0x7f3db7c98d60>,
#   <matplotlib.axis.XTick at 0x7f3db7cb4310>,
#   <matplotlib.axis.XTick at 0x7f3db7cb4dc0>,
#   <matplotlib.axis.XTick at 0x7f3db7cb78b0>,
#   <matplotlib.axis.XTick at 0x7f3db7cbe3a0>,
#   <matplotlib.axis.XTick at 0x7f3db7cb4640>,
#   <matplotlib.axis.XTick at 0x7f3db7cbedc0>,
#   <matplotlib.axis.XTick at 0x7f3db7c458b0>],
#  [Text(1, 0, '2021-10-17 21:25:58'),
#   Text(25, 0, '2021-10-17 20:30:58'),
#   Text(49, 0, '2021-10-17 22:45:58'),
#   Text(73, 0, '2021-10-17 18:46:00'),
#   Text(97, 0, '2021-10-17 02:40:58'),
#   Text(121, 0, '2021-10-17 16:50:58'),
#   Text(145, 0, '2021-10-17 04:30:59'),
#   Text(169, 0, '2021-10-17 01:26:00'),
#   Text(193, 0, '2021-10-17 16:25:58'),
#   Text(217, 0, '2021-10-17 09:25:58'),
#   Text(241, 0, '2021-10-17 14:15:59'),
#   Text(265, 0, '2021-10-17 03:05:59')])

# %%
#Based on the time series plots from the individual day dataframe/subset. I determined an anomaly is probably 42 and greater
#Now create a function that gos through and identifies an anomaly.
def anomaly_detec(x):
    anomaly_sum=0
    if x >= 42:
        anomaly_sum +=1
    else:
        pass
    return anomaly_sum

# %%
anomaly_count = rc_device_atlmax_1012['value'].apply(anomaly_detec)
anomaly_count
# Out:
# 206857    0
# 207088    0
# 207165    0
# 207327    0
# 207404    1
#          ..
# 415403    1
# 416029    0
# 416418    0
# 416649    1
# 417283    0
# Name: value, Length: 269, dtype: int64

# %%
anomaly_sum = anomaly_count.sum()
anomaly_sum
# Out:
# 67

# %%
#There are 67 anomalys in the day 10/12
#now we should repeat this for all seven days and create a Dictionary to input the day with the anomally count.

# %%
#Instead we decided to apply the function to the value column of the entire atlanta max dataframe from my one device to find the anaomalys of the maxes and then add the count to a column named anomaly ttl. 
rc_device_atlmax['anomaly ttl'] = rc_device_atlmax['value'].apply(anomaly_detec)
# Out:
# /tmp/ipykernel_1312869/1420287573.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rc_device_atlmax['anomaly ttl'] = rc_device_atlmax['value'].apply(anomaly_detec)

# %%
rc_device_atlmax
# Out:
#                        time                   deviceid          tool  \
# 1       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency
# 78      2021-10-16 11:05:58  nm-mngd-20210518-075ab2f0  ping_latency
# 155     2021-10-16 09:06:01  nm-mngd-20210518-075ab2f0  ping_latency
# 236     2021-10-16 07:10:59  nm-mngd-20210518-075ab2f0  ping_latency
# 313     2021-10-16 05:50:59  nm-mngd-20210518-075ab2f0  ping_latency
# ...                     ...                        ...           ...
# 469148  2021-10-26 12:00:58  nm-mngd-20210518-075ab2f0  ping_latency
# 469225  2021-10-26 12:10:57  nm-mngd-20210518-075ab2f0  ping_latency
# 469302  2021-10-26 04:06:01  nm-mngd-20210518-075ab2f0  ping_latency
# 469379  2021-10-26 11:26:01  nm-mngd-20210518-075ab2f0  ping_latency
# 469456  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  ping_latency
#
#        direction protocol   target  pktloss method    zip      isp   value  \
# 1            rtt     icmp  Atlanta      0.0    max  60615  xfinity  40.056
# 78           rtt     icmp  Atlanta      0.0    max  60615  xfinity  42.617
# 155          rtt     icmp  Atlanta      0.0    max  60615  xfinity  39.620
# 236          rtt     icmp  Atlanta      0.0    max  60615  xfinity  39.826
# 313          rtt     icmp  Atlanta      0.0    max  60615  xfinity  39.339
# ...          ...      ...      ...      ...    ...    ...      ...     ...
# 469148       rtt     icmp  Atlanta      0.0    max  60615  xfinity  43.628
# 469225       rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.233
# 469302       rtt     icmp  Atlanta      0.0    max  60615  xfinity  42.979
# 469379       rtt     icmp  Atlanta      0.0    max  60615  xfinity  38.386
# 469456       rtt     icmp  Atlanta      0.0    max  60615  xfinity  37.600
#
#        topic   annonipaddr  ipaddrchanged  hour        date  anomaly ttl
# 1       beta  98.206.160.0              0     3  2021-10-16            0
# 78      beta  98.206.160.0              0    11  2021-10-16            1
# 155     beta  98.206.160.0              0     9  2021-10-16            0
# 236     beta  98.206.160.0              0     7  2021-10-16            0
# 313     beta  98.206.160.0              0     5  2021-10-16            0
# ...      ...           ...            ...   ...         ...          ...
# 469148  beta  98.206.160.0              0    12  2021-10-26            1
# 469225  beta  98.206.160.0              0    12  2021-10-26            0
# 469302  beta  98.206.160.0              0     4  2021-10-26            1
# 469379  beta  98.206.160.0              0    11  2021-10-26            0
# 469456  beta  98.206.160.0              0     6  2021-10-26            0
#
# [6020 rows x 17 columns]

# %%
#Used groupby and sum to count the anomalys for each day
anomally_device1max= rc_device_atlmax.groupby('date')[['anomaly ttl']].sum()

# %%
anomally_device1max
# Out:
#             anomaly ttl
# date
# 2021-09-30            2
# 2021-10-01           18
# 2021-10-04           56
# 2021-10-05           57
# 2021-10-06           64
# 2021-10-07           66
# 2021-10-08           31
# 2021-10-11           45
# 2021-10-12           67
# 2021-10-13           59
# 2021-10-14           33
# 2021-10-15           71
# 2021-10-16           92
# 2021-10-17           89
# 2021-10-18           95
# 2021-10-19           88
# 2021-10-20           61
# 2021-10-21           68
# 2021-10-22           75
# 2021-10-23           83
# 2021-10-24          115
# 2021-10-25           79
# 2021-10-26           87
# 2021-10-27           74
# 2021-10-28           19
