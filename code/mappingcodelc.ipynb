# %%
import pandas as pd

# %%
censusblock = pd.read_csv('../code/CensusBlockTIGER2010.csv')
censusblock
# Out:
#                                                 the_geom  STATEFP10  \
# 0      MULTIPOLYGON (((-87.6290679994106 41.769086000...         17
# 1      MULTIPOLYGON (((-87.6341179992764 41.774465999...         17
# 2      MULTIPOLYGON (((-87.63485400018324 41.77263300...         17
# 3      MULTIPOLYGON (((-87.73841099998789 41.85913100...         17
# 4      MULTIPOLYGON (((-87.73217300001724 41.85476400...         17
# ...                                                  ...        ...
# 46352  MULTIPOLYGON (((-87.69323300029735 41.92767000...         17
# 46353  MULTIPOLYGON (((-87.69320200086439 41.92666600...         17
# 46354  MULTIPOLYGON (((-87.67758599991872 41.91623799...         17
# 46355  MULTIPOLYGON (((-87.67397599916275 41.91782700...         17
# 46356  MULTIPOLYGON (((-87.69682600015756 41.92340400...         17
#
#        COUNTYFP10  TRACTCE10  BLOCKCE10          GEOID10      NAME10  \
# 0              31     690300       2010  170316903002010  Block 2010
# 1              31     680900       3007  170316809003007  Block 3007
# 2              31     680900       3013  170316809003013  Block 3013
# 3              31     290900       4019  170312909004019  Block 4019
# 4              31     292500       4016  170312925004016  Block 4016
# ...           ...        ...        ...              ...         ...
# 46352          31     220300       1028  170312203001028  Block 1028
# 46353          31     220300       1030  170312203001030  Block 1030
# 46354          31     831000       2014  170318310002014  Block 2014
# 46355          31     831000       2001  170318310002001  Block 2001
# 46356          31     221400       1007  170312214001007  Block 1007
#
#        TRACT_BLOC
# 0      6903002010
# 1      6809003007
# 2      6809003013
# 3      2909004019
# 4      2925004016
# ...           ...
# 46352  2203001028
# 46353  2203001030
# 46354  8310002014
# 46355  8310002001
# 46356  2214001007
#
# [46357 rows x 8 columns]

# %%
import geopandas as gpd
#from shapely.geometry import Point

# %%
import pandas as pd
import numpy as np
from shapely.wkt import loads

# %%
deviceid = pd.read_csv('../data/device-to-block-map.csv')
deviceid
# Out:
#     Unnamed: 0 device_id          geoid10
# 0            0      e01c  170313501001010
# 1            1      40d7  170317402002002
# 2            2      05f0  170318398002014
# 3            3      98ab  170311403011000
# 4            4      1185  170310204002009
# ..         ...       ...              ...
# 93          97      71c4  170318309002016
# 94          98      a3d5  170312211001016
# 95          99      0b6f  170312206011003
# 96         100      4a4d  170312206012001
# 97         101      d30d  170314108002001
#
# [98 rows x 3 columns]

# %%
censusblock = gpd.read_file('../code/CensusBlockTIGER2010.csv')

censusblock.geometry = censusblock['the_geom'].apply(loads)

# %%
censusblock
# Out:
#                                                 the_geom STATEFP10 COUNTYFP10  \
# 0      MULTIPOLYGON (((-87.6290679994106 41.769086000...        17        031
# 1      MULTIPOLYGON (((-87.6341179992764 41.774465999...        17        031
# 2      MULTIPOLYGON (((-87.63485400018324 41.77263300...        17        031
# 3      MULTIPOLYGON (((-87.73841099998789 41.85913100...        17        031
# 4      MULTIPOLYGON (((-87.73217300001724 41.85476400...        17        031
# ...                                                  ...       ...        ...
# 46352  MULTIPOLYGON (((-87.69323300029735 41.92767000...        17        031
# 46353  MULTIPOLYGON (((-87.69320200086439 41.92666600...        17        031
# 46354  MULTIPOLYGON (((-87.67758599991872 41.91623799...        17        031
# 46355  MULTIPOLYGON (((-87.67397599916275 41.91782700...        17        031
# 46356  MULTIPOLYGON (((-87.69682600015756 41.92340400...        17        031
#
#       TRACTCE10 BLOCKCE10          GEOID10      NAME10  TRACT_BLOC  \
# 0        690300      2010  170316903002010  Block 2010  6903002010
# 1        680900      3007  170316809003007  Block 3007  6809003007
# 2        680900      3013  170316809003013  Block 3013  6809003013
# 3        290900      4019  170312909004019  Block 4019  2909004019
# 4        292500      4016  170312925004016  Block 4016  2925004016
# ...         ...       ...              ...         ...         ...
# 46352    220300      1028  170312203001028  Block 1028  2203001028
# 46353    220300      1030  170312203001030  Block 1030  2203001030
# 46354    831000      2014  170318310002014  Block 2014  8310002014
# 46355    831000      2001  170318310002001  Block 2001  8310002001
# 46356    221400      1007  170312214001007  Block 1007  2214001007
#
#                                                 geometry
# 0      MULTIPOLYGON (((-87.62907 41.76909, -87.62905 ...
# 1      MULTIPOLYGON (((-87.63412 41.77447, -87.63410 ...
# 2      MULTIPOLYGON (((-87.63485 41.77263, -87.63522 ...
# 3      MULTIPOLYGON (((-87.73841 41.85913, -87.73842 ...
# 4      MULTIPOLYGON (((-87.73217 41.85476, -87.73226 ...
# ...                                                  ...
# 46352  MULTIPOLYGON (((-87.69323 41.92767, -87.69385 ...
# 46353  MULTIPOLYGON (((-87.69320 41.92667, -87.69351 ...
# 46354  MULTIPOLYGON (((-87.67759 41.91624, -87.67759 ...
# 46355  MULTIPOLYGON (((-87.67398 41.91783, -87.67397 ...
# 46356  MULTIPOLYGON (((-87.69683 41.92340, -87.69683 ...
#
# [46357 rows x 9 columns]

# %%
censusblock.plot()
# Out:
# <Axes: >

# %%
censusblock = censusblock[['GEOID10', 'geometry']]
censusblock
# Out:
#                GEOID10                                           geometry
# 0      170316903002010  MULTIPOLYGON (((-87.62907 41.76909, -87.62905 ...
# 1      170316809003007  MULTIPOLYGON (((-87.63412 41.77447, -87.63410 ...
# 2      170316809003013  MULTIPOLYGON (((-87.63485 41.77263, -87.63522 ...
# 3      170312909004019  MULTIPOLYGON (((-87.73841 41.85913, -87.73842 ...
# 4      170312925004016  MULTIPOLYGON (((-87.73217 41.85476, -87.73226 ...
# ...                ...                                                ...
# 46352  170312203001028  MULTIPOLYGON (((-87.69323 41.92767, -87.69385 ...
# 46353  170312203001030  MULTIPOLYGON (((-87.69320 41.92667, -87.69351 ...
# 46354  170318310002014  MULTIPOLYGON (((-87.67759 41.91624, -87.67759 ...
# 46355  170318310002001  MULTIPOLYGON (((-87.67398 41.91783, -87.67397 ...
# 46356  170312214001007  MULTIPOLYGON (((-87.69683 41.92340, -87.69683 ...
#
# [46357 rows x 2 columns]

# %%
idcensusblock = pd.merge(deviceid, censusblock, left_on='geoid10', right_on='GEOID10', how='left')
idcensusblock = idcensusblock.drop(['Unnamed: 0', 'GEOID10'], axis=1)
idcensusblock
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 idcensusblock = pd.merge(deviceid, censusblock, left_on='geoid10', right_on='GEOID10', how='left')
#       2 idcensusblock = idcensusblock.drop(['Unnamed: 0', 'GEOID10'], axis=1)
#       3 idcensusblock
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/reshape/merge.py:148, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     131 @Substitution("\nleft : DataFrame or named Series")
#     132 @Appender(_merge_doc, indents=0)
#     133 def merge(
#    (...)
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#     151         how=how,
#     152         on=on,
#     153         left_on=left_on,
#     154         right_on=right_on,
#     155         left_index=left_index,
#     156         right_index=right_index,
#     157         sort=sort,
#     158         suffixes=suffixes,
#     159         indicator=indicator,
#     160         validate=validate,
#     161     )
#     162     return op.get_result(copy=copy)
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/reshape/merge.py:741, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     733 (
#     734     self.left_join_keys,
#     735     self.right_join_keys,
#     736     self.join_names,
#     737 ) = self._get_merge_keys()
#     739 # validate the merge keys dtypes. We may need to coerce
#     740 # to avoid incompatible dtypes
# --> 741 self._maybe_coerce_merge_keys()
#     743 # If argument passed to validate,
#     744 # check if columns specified as unique
#     745 # are in fact unique.
#     746 if validate is not None:
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1401, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1395     # unless we are merging non-string-like with string-like
#    1396     elif (
#    1397         inferred_left in string_types and inferred_right not in string_types
#    1398     ) or (
#    1399         inferred_right in string_types and inferred_left not in string_types
#    1400     ):
# -> 1401         raise ValueError(msg)
#    1403 # datetimelikes must match exactly
#    1404 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on int64 and object columns. If you wish to proceed you should use pd.concat
