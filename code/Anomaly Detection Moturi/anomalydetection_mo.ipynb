# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn.objects as so

# %%
columns = ['time','deviceid','tool','direction','protocol','target','pktloss','method','zip','isp','value','topic','annonipaddr','ipaddrchanged']

# %%
matt_device = pd.read_csv('/srv/data/my_shared_data_folder/internet-equity/device_data_oct21/nm-mngd-20210518-005bb669.csv', names=columns)
matt_device
# Out:
#                        time                   deviceid           tool  \
# 0       2021-10-16 15:21:00  nm-mngd-20210518-005bb669   ping_latency
# 1       2021-10-16 15:21:00  nm-mngd-20210518-005bb669   ping_latency
# 2       2021-10-16 15:21:00  nm-mngd-20210518-005bb669   ping_latency
# 3       2021-10-16 15:21:00  nm-mngd-20210518-005bb669   ping_latency
# 4       2021-10-16 15:21:00  nm-mngd-20210518-005bb669   ping_latency
# ...                     ...                        ...            ...
# 621004  2021-10-26 14:05:57  nm-mngd-20210518-005bb669  last_mile_rtt
# 621005  2021-10-26 14:05:57  nm-mngd-20210518-005bb669  last_mile_rtt
# 621006  2021-10-26 14:05:57  nm-mngd-20210518-005bb669  last_mile_rtt
# 621007  2021-10-26 14:05:57  nm-mngd-20210518-005bb669  last_mile_rtt
# 621008  2021-10-26 14:05:57  nm-mngd-20210518-005bb669  last_mile_rtt
#
#        direction protocol      target  pktloss     method    zip       isp  \
# ...

# %%
atlanta_server = matt_device.loc[matt_device['target'] == 'Atlanta']
atlanta_server#atlanta_server.ping_latency.unique()
# Out:
#                        time                   deviceid          tool  \
# 0       2021-10-16 15:21:00  nm-mngd-20210518-005bb669  ping_latency
# 1       2021-10-16 15:21:00  nm-mngd-20210518-005bb669  ping_latency
# 2       2021-10-16 15:21:00  nm-mngd-20210518-005bb669  ping_latency
# 3       2021-10-16 15:21:00  nm-mngd-20210518-005bb669  ping_latency
# 77      2021-10-16 00:00:59  nm-mngd-20210518-005bb669  ping_latency
# ...                     ...                        ...           ...
# 620858  2021-10-26 14:15:58  nm-mngd-20210518-005bb669  ping_latency
# 620932  2021-10-26 14:05:57  nm-mngd-20210518-005bb669  ping_latency
# 620933  2021-10-26 14:05:57  nm-mngd-20210518-005bb669  ping_latency
# 620934  2021-10-26 14:05:57  nm-mngd-20210518-005bb669  ping_latency
# 620935  2021-10-26 14:05:57  nm-mngd-20210518-005bb669  ping_latency
#
#        direction protocol   target  pktloss method    zip       isp   value  \
# ...

# %%
atlanta_max = atlanta_server.loc[atlanta_server['method'] == 'max']
atlanta_max
# Out:
#                        time                   deviceid          tool  \
# 1       2021-10-16 15:21:00  nm-mngd-20210518-005bb669  ping_latency
# 78      2021-10-16 00:00:59  nm-mngd-20210518-005bb669  ping_latency
# 161     2021-10-16 15:10:59  nm-mngd-20210518-005bb669  ping_latency
# 238     2021-10-15 20:15:58  nm-mngd-20210518-005bb669  ping_latency
# 319     2021-10-16 03:25:58  nm-mngd-20210518-005bb669  ping_latency
# ...                     ...                        ...           ...
# 620625  2021-10-26 18:25:58  nm-mngd-20210518-005bb669  ping_latency
# 620702  2021-10-26 18:35:57  nm-mngd-20210518-005bb669  ping_latency
# 620779  2021-10-25 20:46:00  nm-mngd-20210518-005bb669  ping_latency
# 620856  2021-10-26 14:15:58  nm-mngd-20210518-005bb669  ping_latency
# 620933  2021-10-26 14:05:57  nm-mngd-20210518-005bb669  ping_latency
#
#        direction protocol   target  pktloss method    zip       isp   value  \
# ...

# %%
def split_hour(x):
    row = x
    return row[11:13]

def split_day(x):
    row = x
    return row[5:10]

atlanta_max["hour"] = atlanta_max["time"].apply(split_hour)
atlanta_max["date"] = atlanta_max["time"].apply(split_day)

atlanta_max
# Out:
# /tmp/ipykernel_1088634/1691280647.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   atlanta_max["hour"] = atlanta_max["time"].apply(split_hour)
# /tmp/ipykernel_1088634/1691280647.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   atlanta_max["date"] = atlanta_max["time"].apply(split_day)
#                        time                   deviceid          tool  \
# 1       2021-10-16 15:21:00  nm-mngd-20210518-005bb669  ping_latency
# ...

# %%
atlanta_max['date'].sample(7,replace=False)
# Out:
# 410021    10-31
# 452476    10-04
# 205429    10-15
# 121666    10-07
# 44878     10-05
# 2645      10-16
# 579651    10-06
# Name: date, dtype: object

# %%
atlanta_max.hour = atlanta_max['hour'].astype('int')
# Out:
# /tmp/ipykernel_1088634/1352471669.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   atlanta_max.hour = atlanta_max['hour'].astype('int')

# %%
atlanta10_7 = atlanta_max.loc[atlanta_max['date'] == '10-07']
atlanta10_7
# Out:
#                        time                   deviceid          tool  \
# 112534  2021-10-07 20:01:01  nm-mngd-20210518-005bb669  ping_latency
# 112611  2021-10-07 19:45:57  nm-mngd-20210518-005bb669  ping_latency
# 113000  2021-10-07 19:30:58  nm-mngd-20210518-005bb669  ping_latency
# 113603  2021-10-07 22:15:58  nm-mngd-20210518-005bb669  ping_latency
# 114065  2021-10-07 20:15:58  nm-mngd-20210518-005bb669  ping_latency
# ...                     ...                        ...           ...
#
nm-mngd-20210518-005bb669  ping_latency
#
#        direction protocol   target  pktloss method    zip       isp   value  \
# ...

# %%
atlanta10_31 = atlanta_max.loc[atlanta_max['date'] == '10-31']
atlanta10_31
# Out:
#                        time                   deviceid          tool  \
# 389997  2021-10-31 03:46:01  nm-mngd-20210518-005bb669  ping_latency
# 390074  2021-10-31 06:41:00  nm-mngd-20210518-005bb669  ping_latency
# 390151  2021-10-31 02:51:00  nm-mngd-20210518-005bb669  ping_latency
# 390228  2021-10-31 09:00:58  nm-mngd-20210518-005bb669  ping_latency
# 390382  2021-10-31 09:31:01  nm-mngd-20210518-005bb669  ping_latency
# ...                     ...                        ...           ...
# 411903  2021-10-31 05:55:57  nm-mngd-20210518-005bb669  ping_latency
# 411980  2021-10-31 09:50:59  nm-mngd-20210518-005bb669  ping_latency
# 412138  2021-10-31 04:01:00  nm-mngd-20210518-005bb669  ping_latency
# 412215  2021-10-31 07:05:58  nm-mngd-20210518-005bb669  ping_latency
# 412292  2021-10-31 16:05:58  nm-mngd-20210518-005bb669  ping_latency
#
#        direction protocol   target  pktloss method    zip       isp   value  \
# ...

# %%
atlanta10_05 = atlanta_max.loc[atlanta_max['date'] == '10-05']
atlanta10_05
# Out:
#                        time                   deviceid          tool  \
# 44801   2021-10-05 10:46:00  nm-mngd-20210518-005bb669  ping_latency
# 44878   2021-10-05 17:10:58  nm-mngd-20210518-005bb669  ping_latency
# 44955   2021-10-05 14:45:58  nm-mngd-20210518-005bb669  ping_latency
# 45032   2021-10-05 06:10:58  nm-mngd-20210518-005bb669  ping_latency
# 45267   2021-10-05 14:20:58  nm-mngd-20210518-005bb669  ping_latency
# ...                     ...                        ...           ...
# 249471  2021-10-05 19:15:58  nm-mngd-20210518-005bb669  ping_latency
# 249625  2021-10-05 21:16:01  nm-mngd-20210518-005bb669  ping_latency
# 250269  2021-10-05 22:15:58  nm-mngd-20210518-005bb669  ping_latency
# 250735  2021-10-05 20:55:58  nm-mngd-20210518-005bb669  ping_latency
# 250812  2021-10-05 19:01:01  nm-mngd-20210518-005bb669  ping_latency
#
#        direction protocol   target  pktloss method    zip       isp   value  \
# ...

# %%
atlanta10_30 = atlanta_max.loc[atlanta_max['date'] == '10-30']
atlanta10_30
# Out:
#                        time                   deviceid          tool  \
# 67310   2021-10-30 17:45:59  nm-mngd-20210518-005bb669  ping_latency
# 67387   2021-10-30 14:21:00  nm-mngd-20210518-005bb669  ping_latency
# 67541   2021-10-30 09:35:58  nm-mngd-20210518-005bb669  ping_latency
# 67618   2021-10-30 10:50:58  nm-mngd-20210518-005bb669  ping_latency
# 67695   2021-10-30 12:10:58  nm-mngd-20210518-005bb669  ping_latency
# ...                     ...                        ...           ...
# 409397  2021-10-30 21:15:58  nm-mngd-20210518-005bb669  ping_latency
# 409555  2021-10-30 22:05:57  nm-mngd-20210518-005bb669  ping_latency
# 409709  2021-10-30 20:55:58  nm-mngd-20210518-005bb669  ping_latency
# 410098  2021-10-30 19:40:59  nm-mngd-20210518-005bb669  ping_latency
# 412061  2021-10-30 19:00:59  nm-mngd-20210518-005bb669  ping_latency
#
#        direction protocol   target  pktloss method    zip       isp   value  \
# ...

# %%
fig,ax =  plt.subplots(figsize = (10, 8))
sns.lineplot(x = "hour", y = "value",
             color = 'red', data = atlanta10_7 ,
             ax = ax)
plt.xticks(np.arange(min(atlanta10_7['hour']),max(atlanta10_7['hour'])+1, 2.0))
# Out:
# ([<matplotlib.axis.XTick at 0x7f048b4d2e50>,
# ...
#  [Text(0.0, 0, '0'),
#   Text(2.0, 0, '2'),
#   Text(4.0, 0, '4'),
#   Text(6.0, 0, '6'),
#   Text(8.0, 0, '8'),
#   Text(10.0, 0, '10'),
#   Text(12.0, 0, '12'),
#   Text(14.0, 0, '14'),
#   Text(16.0, 0, '16'),
#   Text(18.0, 0, '18'),
#   Text(20.0, 0, '20'),
#   Text(22.0, 0, '22')])

# %%
fig,ax =  plt.subplots(figsize = (10, 8))
sns.lineplot(x = "hour", y = "value",
             color = 'blue', data = atlanta10_26 ,
             ax = ax)
plt.xticks(np.arange(min(atlanta10_26['hour']),max(atlanta10_26['hour'])+1, 2.0))
# Out:
# ([<matplotlib.axis.XTick at 0x7f0489bf0d90>,
# ...
#  [Text(0.0, 0, '0'),
#   Text(2.0, 0, '2'),
#   Text(4.0, 0, '4'),
#   Text(6.0, 0, '6'),
#   Text(8.0, 0, '8'),
#   Text(10.0, 0, '10'),
#   Text(12.0, 0, '12'),
#   Text(14.0, 0, '14'),
#   Text(16.0, 0, '16'),
#   Text(18.0, 0, '18'),
#   Text(20.0, 0, '20'),
#   Text(22.0, 0, '22')])

# %%
fig,ax =  plt.subplots(figsize = (10, 8))
sns.lineplot(x = "hour", y = "value",
             color = 'magenta', data = atlanta10_24 ,
             ax = ax)
plt.xticks(np.arange(min(atlanta10_24['hour']),max(atlanta10_24['hour'])+1, 2.0))
# Out:
# ([<matplotlib.axis.XTick at 0x7f0489a92550>,
# ...
#  [Text(0.0, 0, '0'),
#   Text(2.0, 0, '2'),
#   Text(4.0, 0, '4'),
#   Text(6.0, 0, '6'),
#   Text(8.0, 0, '8'),
#   Text(10.0, 0, '10'),
#   Text(12.0, 0, '12'),
#   Text(14.0, 0, '14'),
#   Text(16.0, 0, '16'),
#   Text(18.0, 0, '18'),
#   Text(20.0, 0, '20'),
#   Text(22.0, 0, '22')])

# %%
fig,ax =  plt.subplots(figsize = (10, 8))
sns.lineplot(x = "hour", y = "value",
             color = 'pink', data = atlanta10_25 ,
             ax = ax)
plt.xticks(np.arange(min(atlanta10_25['hour']),max(atlanta10_25['hour'])+1, 2.0))
# Out:
# ([<matplotlib.axis.XTick at 0x7f04898b6400>,
# ...
#  [Text(0.0, 0, '0'),
#   Text(2.0, 0, '2'),
#   Text(4.0, 0, '4'),
#   Text(6.0, 0, '6'),
#   Text(8.0, 0, '8'),
#   Text(10.0, 0, '10'),
#   Text(12.0, 0, '12'),
#   Text(14.0, 0, '14'),
#   Text(16.0, 0, '16'),
#   Text(18.0, 0, '18'),
#   Text(20.0, 0, '20'),
#   Text(22.0, 0, '22')])

# %%
fig,ax =  plt.subplots(figsize = (10, 8))
sns.lineplot(x = "hour", y = "value",
             color = 'yellow', data = atlanta10_31 ,
             ax = ax)
plt.xticks(np.arange(min(atlanta10_31['hour']),max(atlanta10_31['hour'])+1, 2.0))
# Out:
# ([<matplotlib.axis.XTick at 0x7f04899367f0>,
# ...
#  [Text(0.0, 0, '0'),
#   Text(2.0, 0, '2'),
#   Text(4.0, 0, '4'),
#   Text(6.0, 0, '6'),
#   Text(8.0, 0, '8'),
#   Text(10.0, 0, '10'),
#   Text(12.0, 0, '12'),
#   Text(14.0, 0, '14'),
#   Text(16.0, 0, '16'),
#   Text(18.0, 0, '18')])

# %%
def anomaly_detect(latencyvalue):
    anomaly_count = 0
    if latencyvalue >= 25.5:
        anomaly_count +=1
    else:
        pass
    return anomaly_count

# %%
anomaly_sum = atlanta10_7["value"].apply(anomaly_detect)
anomaly_sum
# Out:
# 112534    0
# 112611    0
# 113000    0
# 113603    0
# 114065    0
#          ..
# 590931    0
# 591008    0
# 591085    0
# 591166    0
# 591243    0
# Name: value, Length: 288, dtype: int64

# %%
anomaly_sum.sum()
# Out:
# 43

# %%
atlanta10_7
# Out:
#                        time                   deviceid          tool  \
# 112534  2021-10-07 20:01:01  nm-mngd-20210518-005bb669  ping_latency
# 112611  2021-10-07 19:45:57  nm-mngd-20210518-005bb669  ping_latency
# 113000  2021-10-07 19:30:58  nm-mngd-20210518-005bb669  ping_latency
# 113603  2021-10-07 22:15:58  nm-mngd-20210518-005bb669  ping_latency
# 114065  2021-10-07 20:15:58  nm-mngd-20210518-005bb669  ping_latency
# ...                     ...                        ...           ...
# 590931  2021-10-07 10:50:58  nm-mngd-20210518-005bb669  ping_latency
# 591008  2021-10-07 11:36:01  nm-mngd-20210518-005bb669  ping_latency
# 591085  2021-10-07 02:55:59  nm-mngd-20210518-005bb669  ping_latency
# 591166  2021-10-07 14:21:00  nm-mngd-20210518-005bb669  ping_latency
# 591243  2021-10-07 01:30:59  nm-mngd-20210518-005bb669  ping_latency
#
#        direction protocol   target  pktloss method    zip       isp   value  \
# ...
