# %%
import pandas as pd
import numpy as np
rc_device = pd.read_csv('/srv/data/my_shared_data_folder/internet-equity/device_data_oct21/nm-mngd-20210518-075ab2f0.csv')
rc_device
# Out:
#         2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency  rtt  \
# 0       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency  rtt
# 1       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency  rtt
# 2       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency  rtt
# 3       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency  rtt
# 4       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0   ping_latency  rtt
# ...                     ...                        ...            ...  ...
# 469526  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt  rtt
# 469527  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt  rtt
# 469528  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt  rtt
# 469529  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt  rtt
# 469530  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  last_mile_rtt  rtt
#
# ...

# %%
atlanta_device = rc_device.loc[rc_device['Atlanta'] == 'Atlanta']
atlanta_device
# Out:
#         2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt  \
# 0       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 1       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 2       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 76      2021-10-16 11:05:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 77      2021-10-16 11:05:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# ...                     ...                        ...           ...  ...
# 469380  2021-10-26 11:26:01  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469454  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469455  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469456  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469457  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt
#
#         icmp  Atlanta    0   avg  60615  xfinity  37.488  beta  98.206.160.0  \
# ...

# %%
atlanta_device_max = atlanta_device.loc[atlanta_device['avg'] == 'max']
atlanta_device_max
# Out:
#         2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt  \
# 0       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 77      2021-10-16 11:05:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 154     2021-10-16 09:06:01  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 235     2021-10-16 07:10:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 312     2021-10-16 05:50:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# ...                     ...                        ...           ...  ...
# 469147  2021-10-26 12:00:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469224  2021-10-26 12:10:57  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469301  2021-10-26 04:06:01  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469378  2021-10-26 11:26:01  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469455  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt
#
#         icmp  Atlanta    0  avg  60615  xfinity  37.488  beta  98.206.160.0  \
# ...

# %%
atlanta_device_min = atlanta_device.loc[atlanta_device['avg'] == 'min']
atlanta_device_min
# Out:
#         2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt  \
# 2       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 79      2021-10-16 11:05:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 156     2021-10-16 09:06:01  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 237     2021-10-16 07:10:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 314     2021-10-16 05:50:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# ...                     ...                        ...           ...  ...
# 469149  2021-10-26 12:00:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469226  2021-10-26 12:10:57  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469303  2021-10-26 04:06:01  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469380  2021-10-26 11:26:01  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469457  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt
#
#         icmp  Atlanta    0  avg  60615  xfinity  37.488  beta  98.206.160.0  \
# ...

# %%
atlanta_device_mdev = atlanta_device.loc[atlanta_device['avg'] == 'mdev']
atlanta_device_mdev
# Out:
#         2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt  \
# 1       2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 78      2021-10-16 11:05:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 155     2021-10-16 09:06:01  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 236     2021-10-16 07:10:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 313     2021-10-16 05:50:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# ...                     ...                        ...           ...  ...
# 469148  2021-10-26 12:00:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469225  2021-10-26 12:10:57  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469302  2021-10-26 04:06:01  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469379  2021-10-26 11:26:01  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469456  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt
#
#         icmp  Atlanta    0   avg  60615  xfinity  37.488  beta  98.206.160.0  \
# ...

# %%
atlanta_device_avg = atlanta_device.loc[atlanta_device['avg'] == 'avg']
atlanta_device_avg
# Out:
#         2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt  \
# 76      2021-10-16 11:05:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 153     2021-10-16 09:06:01  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 234     2021-10-16 07:10:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 311     2021-10-16 05:50:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 388     2021-10-16 01:40:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# ...                     ...                        ...           ...  ...
# 469146  2021-10-26 12:00:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469223  2021-10-26 12:10:57  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469300  2021-10-26 04:06:01  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469377  2021-10-26 11:26:01  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469454  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt
#
#         icmp  Atlanta    0  avg  60615  xfinity  37.488  beta  98.206.160.0  \
# ...

# %%
atl_min_avg = atlanta_device_avg['2021-10-16 03:40:58'].min()
atl_min_avg
# Out:
# '2021-09-30 19:11:23'

# %%
### This code made the time series map for the average, min, max, and mdev. But the x axis labels are black because its to much data. so we are working on that now but i commented the code out because everytime i have to run all the cells again it takes to long.
#import pandas as pd
#import matplotlib.pyplot as plt
#Making separate plots for the four datasetts
#plt.figure(figsize=(10, 6))
#Dataset 1(max)
#plt.subplot(2, 2, 1) 
#plt.plot(atlanta_device_max['2021-10-16 03:40:58'], atlanta_device_max['37.488'])
#plt.xlabel('Time')
#plt.ylabel('Data')
#plt.title('Atl Max Lat.')
#Dataset 2(min)
#plt.subplot(2, 2, 2)
#plt.plot(atlanta_device_min['2021-10-16 03:40:58'], atlanta_device_min['37.488'])
#plt.xlabel('Time')
#plt.ylabel('Data')
#plt.title('Atl Min Lat.')
#Dataset 3(mdev)
#plt.subplot(2, 2, 3)
#plt.plot(atlanta_device_mdev['2021-10-16 03:40:58'], atlanta_device_mdev['37.488'])
#plt.xlabel('Time')
#plt.ylabel('Data')
#plt.title('Atl Mdev Lat.')
#Dataset 4(avg)
#plt.subplot(2, 2, 4)
#plt.plot(atlanta_device_avg['2021-10-16 03:40:58'], atlanta_device_avg['37.488'])
#plt.xlabel('Time')
#plt.ylabel('Data')
#plt.title('Atl Avg Lat.')
#fix spacing between subplots
#plt.tight_layout()
#Show plots
#plt.show()
#rotate the ticks
#plt.xticks(rotation=45)

# %%
#we wrote a function to seperate the date and time then apply a date column and a time column..
#i dont know where the code went that I seperated and added the data column. but its the same function I did for the time split.
def split_hour(x):
    row = x
    return row[11:13]

atlanta_device_avg.loc[:,"hour"] = atlanta_device_avg.loc[:,"2021-10-16 03:40:58"].apply(split_hour)
# Out:
# /tmp/ipykernel_988520/1153171421.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   atlanta_device_avg.loc[:,"hour"] = atlanta_device_avg.loc[:,"2021-10-16 03:40:58"].apply(split_hour)

# %%
atlanta_device_avg.head()
# Out:
#      2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt  icmp  \
# 76   2021-10-16 11:05:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt  icmp
# 153  2021-10-16 09:06:01  nm-mngd-20210518-075ab2f0  ping_latency  rtt  icmp
# 234  2021-10-16 07:10:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt  icmp
# 311  2021-10-16 05:50:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt  icmp
# 388  2021-10-16 01:40:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt  icmp
#
#      Atlanta    0  avg  60615  xfinity  37.488  beta  98.206.160.0  0.1  \
# 76   Atlanta  0.0  avg  60615  xfinity  37.849  beta  98.206.160.0    0
# 153  Atlanta  0.0  avg  60615  xfinity  37.539  beta  98.206.160.0    0
# 234  Atlanta  0.0  avg  60615  xfinity  37.598  beta  98.206.160.0    0
# 311  Atlanta  0.0  avg  60615  xfinity  37.085  beta  98.206.160.0    0
# 388  Atlanta  0.0  avg  60615  xfinity  37.313  beta  98.206.160.0    0
#
#       date hour
# 76   10-16   11
# 153  10-16   09
# 234  10-16   07
# ...

# %%
atlanta_device_avg.tail()
# Out:
#         2021-10-16 03:40:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt  \
# 469146  2021-10-26 12:00:58  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469223  2021-10-26 12:10:57  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469300  2021-10-26 04:06:01  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469377  2021-10-26 11:26:01  nm-mngd-20210518-075ab2f0  ping_latency  rtt
# 469454  2021-10-26 06:55:59  nm-mngd-20210518-075ab2f0  ping_latency  rtt
#
#         icmp  Atlanta    0  avg  60615  xfinity  37.488  beta  98.206.160.0  \
# 469146  icmp  Atlanta  0.0  avg  60615  xfinity  37.952  beta  98.206.160.0
# 469223  icmp  Atlanta  0.0  avg  60615  xfinity  37.498  beta  98.206.160.0
# 469300  icmp  Atlanta  0.0  avg  60615  xfinity  37.591  beta  98.206.160.0
# 469377  icmp  Atlanta  0.0  avg  60615  xfinity  37.789  beta  98.206.160.0
# 469454  icmp  Atlanta  0.0  avg  60615  xfinity  36.785  beta  98.206.160.0
#
#         0.1   date hour
# 469146    0  10-26   12
# ...

# %%
atlanta_device_avg.hour = atlanta_device_avg['hour'].astype('int')
print(atlanta_device_avg.dtypes)
# Out:
# 2021-10-16 03:40:58           object
# nm-mngd-20210518-075ab2f0     object
# ping_latency                  object
# rtt                           object
# icmp                          object
# Atlanta                       object
# 0                            float64
# avg                           object
# 60615                          int64
# xfinity                       object
# 37.488                       float64
# beta                          object
# 98.206.160.0                  object
# 0.1                            int64
# date                          object
# hour                           int64
# dtype: object
# /tmp/ipykernel_988520/2505833230.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#atlanta_device_avgx means the min hour 
atlanta_device_avgx= atlanta_device_avg['hour'].min()
atlanta_device_avgx
# Out:
# 0

# %%
#atlanta_device_avgy means the max hour 
atlanta_device_avgy = atlanta_device_avg['hour'].max()
atlanta_device_avgy
# Out:
# 23

# %%
#atlanta_device_avgm means grouping by the latency of a specfic hour and finding the max
atlanta_device_avgm = atlanta_device_avg.groupby('hour')[['37.488']].max()
atlanta_device_avgm
# Out:
#       37.488
# hour
# 0     39.991
# 1     40.410
# 2     42.601
# 3     40.798
# 4     43.536
# 5     40.714
# 6     40.895
# 7     41.199
# 8     44.021
# 9     52.104
# 10    40.163
# 11    40.810
# 12    40.359
# 13    41.960
# 14    41.952
# 15    41.166
# 16    41.076
# 17    46.996
# 18    41.112
# 19    43.707
# 20    46.714
# 21    42.034
# 22    42.616
# 23    40.369

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

fig,ax =  plt.subplots(figsize = ( 10, 8))
sns.lineplot( x = "hour", y = "37.488",
             color = 'blue', data = atlanta_device_avgm,
             ax = ax)
plt.xticks(np.arange(min(atlanta_device_avgx), max(atlanta_device_avgy)+1, 1.0))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 9
#       5 fig,ax =  plt.subplots(figsize = ( 10, 8))
#       6 sns.lineplot( x = "hour", y = "37.488",
#       7              color = 'blue', data = atlanta_device_avgm,
#       8              ax = ax)
# ----> 9 plt.xticks(np.arange(min(atlanta_device_avgx), max(atlanta_device_avgy)+1, 1.0))
#
# TypeError: 'numpy.int64' object is not iterable
