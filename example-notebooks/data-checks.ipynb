# %%
import pandas as pd
import os

data_path = "../data/netrics/2022-07-01-2022-08-01"

# %%
speedtests = pd.read_csv(os.path.join(data_path, "speedtest.csv"))

# %%
print(speedtests.shape)
speedtests.columns
# Out:
# (77728, 5)
# Index(['Time', 'Direction', 'Tool', 'Speed', 'ID'], dtype='object')

# %%
print(f"Date range: {speedtests.Time.min()} - {speedtests.Time.max()}")
# Out:
# Date range: 2022-06-30 19:00:03.600651-05:00 - 2022-07-31 18:57:24.493189-05:00

# %%
pd.options.display.max_rows = 300
print(speedtests.Direction.unique())
print(speedtests.Tool.unique())
print("Speed summaries\n", speedtests.Speed.describe())
print("Number of devices: ", speedtests.ID.nunique())
speedtests.groupby(["ID", "Tool"]).size().reset_index()
# Out:
# ['download' 'upload']
# ['iPerf3 (TCP)' 'iPerf3 (UDP)' 'ndt7' 'ookla']
# Speed summaries
#  count     77728.000000
# mean        244.730163
# std        2266.459796
# min     -625470.931357
# 25%          13.834763
# 50%          95.686062
# 75%         373.130278
# max         956.706272
# Name: Speed, dtype: float64
# Number of devices:  87
#                             ID          Tool     0
# 0    nm-mngd-20210518-005bb669  iPerf3 (TCP)    59
# 1    nm-mngd-20210518-005bb669  iPerf3 (UDP)    86
# 2    nm-mngd-20210518-005bb669          ndt7    98
# 3    nm-mngd-20210518-005bb669         ookla    98
# 4    nm-mngd-20210518-0ca06c37  iPerf3 (TCP)   977
# ..                         ...           ...   ...
# 340  nm-mngd-20220623-59224a4d         ookla   132
# 341  nm-mngd-20220628-07c02d28  iPerf3 (TCP)  1281
# 342  nm-mngd-20220628-07c02d28  iPerf3 (UDP)   100
# 343  nm-mngd-20220628-07c02d28          ndt7  1314
# 344  nm-mngd-20220628-07c02d28         ookla  1310
#
# [345 rows x 3 columns]

# %%
ping_latency = pd.read_csv(os.path.join(data_path, "ping_latency.csv"))

# %%
print(ping_latency.shape)
ping_latency.columns
# Out:
# (8522263, 6)
# Index(['Time', 'RTT', 'Measurement', 'ID', 'Destination', 'Method'], dtype='object')

# %%
print(f"Date range: {ping_latency.Time.min()} - {ping_latency.Time.max()}")
# Out:
# Date range: 2022-06-30 19:00:03.600651-05:00 - 2022-07-31 18:59:05.177235-05:00

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)
print(ping_latency.Measurement.unique())
print(ping_latency.Destination.unique())
print(ping_latency.Method.unique())
print("Ping latency summaries\n", ping_latency.RTT.describe())
print("Number of devices: ", ping_latency.ID.nunique())
ping_latency.groupby(["ID"]).size().reset_index()
# Out:
# ['ping_latency' 'last_mile_rtt']
# ['Atlanta' 'Last Mile' 'Denver' 'Washington' 'amazon' 'facebook' 'google'
#  'suntimes' 'tribune' 'uchicago' 'wikipedia' 'youtube']
# ['Avg' 'Min']
# Ping latency summaries
#  count   8522263.00000
# mean         20.19558
# std          50.88419
# min           0.35100
# 25%           8.66700
# 50%          12.50900
# 75%          28.02000
# max        5722.80500
# Name: RTT, dtype: float64
# Number of devices:  86
#                            ID       0
# 61  nm-mngd-20220218-178af0c4  118894
# 62  nm-mngd-20220218-486047bf  118770
# 63  nm-mngd-20220218-77d108b6  118876
# 64  nm-mngd-20220221-bffd128d  118987
# 65  nm-mngd-20220224-e5552881  118864
# 66  nm-mngd-20220301-fac88cb2  118901
# 67  nm-mngd-20220505-13e9adcd   33643
# 68  nm-mngd-20220505-23cccfed  117916
# 69  nm-mngd-20220505-30005b68  111367
# 70  nm-mngd-20220505-3740f507  119003
# 71  nm-mngd-20220505-4d0b6753   28352
# 72  nm-mngd-20220505-7db0ce31  116278
# 73  nm-mngd-20220505-a8149041  115307
# 74  nm-mngd-20220505-dcd76b53  118092
# 75  nm-mngd-20220506-2f996174  118925
# 76  nm-mngd-20220506-3809e1bb  118866
# 77  nm-mngd-20220506-8652c367  117630
# 78  nm-mngd-20220506-98c85a91  118732
# 79  nm-mngd-20220506-bc8d265f   55024
# 80  nm-mngd-20220621-5913a3d5  113918
# 81  nm-mngd-20220621-eb793ac0  119005
# 82  nm-mngd-20220622-299d1347  118371
# 83  nm-mngd-20220622-a9810b6f  117991
# 84  nm-mngd-20220623-59224a4d  119025
# 85  nm-mngd-20220628-07c02d28  102164

# %%
lul = pd.read_csv(os.path.join(data_path, "lul.csv"))

# %%
print(lul.shape)
lul.columns
# Out:
# (24357, 7)
# Index(['Time', 'RTT', 'Measurement', 'ID', 'Protocol', 'Direction',
#        'Destination'],
#       dtype='object')

# %%
print(f"Date range: {lul.Time.min()} - {lul.Time.max()}")
# Out:
# Date range: 2022-06-30 19:03:13.861787-05:00 - 2022-07-31 18:51:04.732598-05:00

# %%
print(lul.Measurement.unique())
print(lul.Direction.unique())
print(lul.Protocol.unique())
print(lul.Destination.unique())
print("LUL summaries\n", lul.RTT.describe())
print("Number of devices: ", lul.ID.nunique())
lul.groupby(["ID"]).size().reset_index()
# Out:
# ['oplat']
# ['upload' 'download']
# ['icmp' 'tcp']
# ['abbott.cs.uchicago.edu']
# LUL summaries
#  count   24357.00000
# mean      140.67426
# std       346.43357
# min        -0.00000
# 25%        21.94488
# 50%        56.36034
# 75%       128.10157
# max      5793.71264
# Name: RTT, dtype: float64
# Number of devices:  86
#                            ID     0
# 0   nm-mngd-20210518-005bb669    87
# 1   nm-mngd-20210518-0ca06c37  1471
# 2   nm-mngd-20210518-19941862   134
# 3   nm-mngd-20210518-28abe768   293
# 4   nm-mngd-20210518-a312bf95  1059
# 5   nm-mngd-20210518-c22d980b   495
# 6   nm-mngd-20210518-f2242dfd  1050
# 7   nm-mngd-20210519-84594993    54
# 8   nm-mngd-20210519-ee6bcbb8   149
# 9   nm-mngd-20210623-1b49a7fa   138
# 10  nm-mngd-20210915-0e5a8b9f    15
# 11  nm-mngd-20210915-21cdf51f   213
# 12  nm-mngd-20210915-3fb6ba43   273
# 13  nm-mngd-20210915-4489c8bd    42
# 14  nm-mngd-20210915-5042f35e   133
# 15  nm-mngd-20210915-774040d7   126
# 79  nm-mngd-20220506-bc8d265f   163
# 80  nm-mngd-20220621-5913a3d5   117
# 81  nm-mngd-20220621-eb793ac0   120
# 82  nm-mngd-20220622-299d1347   115
# 83  nm-mngd-20220622-a9810b6f   278
# 84  nm-mngd-20220623-59224a4d   114
# 85  nm-mngd-20220628-07c02d28  1922

# %%
lan_bw = pd.read_csv(os.path.join(data_path, "lan_bw.csv"))

# %%
print(lan_bw.shape)
lan_bw.columns
# Out:
# (1978, 5)
# Index(['Time', 'Speed', 'Measurement', 'ID', 'Origin'], dtype='object')

# %%
print(f"Date range: {lan_bw.Time.min()} - {lan_bw.Time.max()}")
# Out:
# Date range: 2022-06-30 19:51:48-05:00 - 2022-07-31 18:32:37-05:00

# %%
print(lan_bw.Measurement.unique())
print(lan_bw.Origin.unique())
print("Speed summaries\n", lan_bw.Speed.describe())
print("Number of devices: ", lan_bw.ID.nunique())
lan_bw.groupby(["ID"]).size().reset_index()
# Out:
# ['lan_bw_client_mbps' 'lan_bw_server_mbps']
# ['Client' 'Netrics']
# Speed summaries
#  count   1978.00000
# mean     249.15335
# std      188.94946
# min        3.10362
# 25%       94.53085
# 50%      186.07520
# 75%      364.14671
# max      940.16417
# Name: Speed, dtype: float64
# Number of devices:  29
#                            ID    0
# 0   nm-mngd-20210518-19941862  140
# 1   nm-mngd-20210518-c22d980b   86
# 2   nm-mngd-20210518-f2242dfd  242
# 3   nm-mngd-20210519-ee6bcbb8    8
# 4   nm-mngd-20210915-3fb6ba43   78
# 5   nm-mngd-20210915-4489c8bd  141
# 6   nm-mngd-20210915-612a3db3   87
# 7   nm-mngd-20210915-8edface4   14
# 8   nm-mngd-20210915-cf796bf1    6
# 9   nm-mngd-20210923-074c086d   50
# 10  nm-mngd-20210924-1ca7f852   12
# 11  nm-mngd-20210924-48964f71  174
# 12  nm-mngd-20210924-8d1e98ab   94
# 13  nm-mngd-20210927-3f24e5b4   52
# 14  nm-mngd-20210927-4def23bd   12
# 15  nm-mngd-20210927-8da43959    2
# 16  nm-mngd-20210927-d8cfa28a   56
# 17  nm-mngd-20210927-f4ccde6b    8
# 18  nm-mngd-20211006-ce55f0f2    4
# 19  nm-mngd-20211210-0e99d30d   87
# 20  nm-mngd-20220217-066fd54b   61
# 21  nm-mngd-20220217-47373932  179
# 22  nm-mngd-20220217-9da01799   34
# 23  nm-mngd-20220218-486047bf   68
# 24  nm-mngd-20220301-fac88cb2   40
# 25  nm-mngd-20220505-23cccfed  120
# 26  nm-mngd-20220505-a8149041   14
# 27  nm-mngd-20220505-dcd76b53  105
# 28  nm-mngd-20220506-98c85a91    4

# %%
hops = pd.read_csv(os.path.join(data_path, "hops_to_google.csv"))

# %%
print(hops.shape)
hops.columns
# Out:
# (641132, 4)
# Index(['Time', 'Hops', 'Measurement', 'ID'], dtype='object')

# %%
print(f"Date range: {hops.Time.min()} - {hops.Time.max()}")
# Out:
# Date range: 2022-06-30 19:00:58.793308-05:00 - 2022-07-31 18:57:29.838862-05:00

# %%
print(hops.Measurement.unique())
print("Hops summaries\n", hops.Hops.describe())
print("Number of devices: ", hops.ID.nunique())
hops.groupby(["ID"]).size().reset_index()
# Out:
# ['hops_to_google']
# Hops summaries
#  count   641132.00000
# mean        11.65103
# std          2.87869
# min          7.00000
# 25%          9.00000
# 50%         12.00000
# 75%         13.00000
# max         20.00000
# Name: Hops, dtype: float64
# Number of devices:  87
#                            ID     0
# 0   nm-mngd-20210518-005bb669  7941
# 1   nm-mngd-20210518-0ca06c37  6713
# 2   nm-mngd-20210518-19941862  8924
# 3   nm-mngd-20210518-28abe768  8861
# 4   nm-mngd-20210518-a312bf95  8135
# 5   nm-mngd-20210518-c22d980b  8885
# 6   nm-mngd-20210518-f2242dfd  8888
# 7   nm-mngd-20210519-84594993  8925
# 8   nm-mngd-20210519-ee6bcbb8  8923
# 9   nm-mngd-20210623-1b49a7fa  8757
# 10  nm-mngd-20210915-0e5a8b9f   280
# 11  nm-mngd-20210915-21cdf51f  8914
# 12  nm-mngd-20210915-3fb6ba43  8921
# 13  nm-mngd-20210915-4489c8bd  8917
# 14  nm-mngd-20210915-5042f35e  7009
# 15  nm-mngd-20210915-612a3db3   685
# 16  nm-mngd-20210915-774040d7  8914
# 17  nm-mngd-20210915-89e40819  8926
# 18  nm-mngd-20210915-8bb64c9a  2251
# 19  nm-mngd-20210915-8d4ba8df  2265
# 20  nm-mngd-20210915-8dd84998  8806
# 21  nm-mngd-20210915-8edface4  8917
# 22  nm-mngd-20210915-9db171c4  1971
# 23  nm-mngd-20210915-a2352afe  2237
# 24  nm-mngd-20210915-a64ec38c  8868
# 25  nm-mngd-20210915-cf796bf1   478
# 26  nm-mngd-20210915-d5f18da9  8018
# 27  nm-mngd-20210915-f4b4a69b  8730
# 28  nm-mngd-20210923-074c086d  8922
# 29  nm-mngd-20210924-1ca7f852  8802
# 30  nm-mngd-20210924-48964f71  8924
# 31  nm-mngd-20210924-77f105f0  8768
# 32  nm-mngd-20210924-872de77e  8900
# 33  nm-mngd-20210924-8d1e98ab  2200
# 34  nm-mngd-20210924-a97dceb2  5135
# 35  nm-mngd-20210924-cbe578f4  8903
# 36  nm-mngd-20210924-fad61185  5562
# 37  nm-mngd-20210927-04dc925c  8850
# 38  nm-mngd-20210927-145c392b  8927
# 39  nm-mngd-20210927-178debb9  8925
# 40  nm-mngd-20210927-1a4f71d4  6670
# 41  nm-mngd-20210927-1aaa32b5  4437
# 42  nm-mngd-20210927-1b5896d3  8927
# 43  nm-mngd-20210927-3f24e5b4  8918
# 44  nm-mngd-20210927-4a1de38c  8925
# 45  nm-mngd-20210927-4def23bd  8919
# 46  nm-mngd-20210927-8da43959  8842
# 47  nm-mngd-20210927-9044c591  8857
# 48  nm-mngd-20210927-cc1bdfb9  8925
# 49  nm-mngd-20210927-d8cfa28a  8810
# 50  nm-mngd-20210927-f4ccde6b  8895
# 51  nm-mngd-20210927-f531ff46  8916
# 52  nm-mngd-20211006-ce55f0f2  1474
# 53  nm-mngd-20211110-9ececc37  3942
# 54  nm-mngd-20211110-ee176ec5   792
# 55  nm-mngd-20211210-0e99d30d  3121
# 56  nm-mngd-20220217-066fd54b  8901
# 57  nm-mngd-20220217-153d4573  8922
# 58  nm-mngd-20220217-23cbb217  8925
# 59  nm-mngd-20220217-47373932  2257
# 60  nm-mngd-20220217-9da01799  8736
# 61  nm-mngd-20220217-d4ed546b  8925
# 62  nm-mngd-20220218-178af0c4  8920
# 63  nm-mngd-20220218-486047bf  8918
# 64  nm-mngd-20220218-77d108b6  8917
# 65  nm-mngd-20220221-bffd128d  8925
# 66  nm-mngd-20220224-e5552881  8916
# 67  nm-mngd-20220301-fac88cb2  8918
# 68  nm-mngd-20220505-13e9adcd  2361
# 69  nm-mngd-20220505-23cccfed  8845
# 70  nm-mngd-20220505-30005b68  8352
# 71  nm-mngd-20220505-3740f507  8926
# 72  nm-mngd-20220505-4d0b6753  2445
# 73  nm-mngd-20220505-7db0ce31  8753
# 74  nm-mngd-20220505-a8149041  8664
# 75  nm-mngd-20220505-dcd76b53  8891
# 76  nm-mngd-20220506-2f996174  8921
# 77  nm-mngd-20220506-3809e1bb  8917
# 78  nm-mngd-20220506-8652c367  8831
# 79  nm-mngd-20220506-98c85a91  8908
# 80  nm-mngd-20220506-bc8d265f  4126
# 81  nm-mngd-20220621-5913a3d5  8547
# 82  nm-mngd-20220621-eb793ac0  8926
# 83  nm-mngd-20220622-299d1347  8883
# 84  nm-mngd-20220622-a9810b6f  8853
# 85  nm-mngd-20220623-59224a4d  8928
# 86  nm-mngd-20220628-07c02d28  7628

# %%
dns = pd.read_csv(os.path.join(data_path, "dns_latency.csv"))

# %%
print(dns.shape)
dns.columns
# Out:
# (1282276, 5)
# Index(['Time', 'Query Time', 'Measurement', 'ID', 'Type'], dtype='object')

# %%
print(f"Date range: {dns.Time.min()} - {dns.Time.max()}")
# Out:
# Date range: 2022-06-30 19:00:58.793308-05:00 - 2022-07-31 18:57:29.838862-05:00

# %%
print(dns.Measurement.unique())
print(dns.Type.unique())
print("DNS summaries\n", dns["Query Time"].describe())
print("Number of devices: ", dns.ID.nunique())
dns.groupby(["ID"]).size().reset_index()
# Out:
# ['dns_latency']
# ['Avg' 'Max']
# DNS summaries
#  count   1282276.00000
# mean         58.64590
# std         187.85177
# min           3.05000
# 25%          22.60000
# 50%          38.40000
# 75%          55.00000
# max        4999.00000
# Name: Query Time, dtype: float64
# Number of devices:  87
#                            ID      0
# 0   nm-mngd-20210518-005bb669  15882
# 1   nm-mngd-20210518-0ca06c37  13426
# 2   nm-mngd-20210518-19941862  17848
# 3   nm-mngd-20210518-28abe768  17722
# 4   nm-mngd-20210518-a312bf95  16270
# 5   nm-mngd-20210518-c22d980b  17770
# 6   nm-mngd-20210518-f2242dfd  17776
# 68  nm-mngd-20220505-13e9adcd   4722
# 69  nm-mngd-20220505-23cccfed  17690
# 70  nm-mngd-20220505-30005b68  16706
# 71  nm-mngd-20220505-3740f507  17852
# 72  nm-mngd-20220505-4d0b6753   4890
# 73  nm-mngd-20220505-7db0ce31  17506
# 74  nm-mngd-20220505-a8149041  17328
# 75  nm-mngd-20220505-dcd76b53  17782
# 76  nm-mngd-20220506-2f996174  17842
# 77  nm-mngd-20220506-3809e1bb  17834
# 78  nm-mngd-20220506-8652c367  17662
# 79  nm-mngd-20220506-98c85a91  17816
# 80  nm-mngd-20220506-bc8d265f   8252
# 81  nm-mngd-20220621-5913a3d5  17094
# 82  nm-mngd-20220621-eb793ac0  17852
# 83  nm-mngd-20220622-299d1347  17766
# 84  nm-mngd-20220622-a9810b6f  17706
# 85  nm-mngd-20220623-59224a4d  17856
# 86  nm-mngd-20220628-07c02d28  15256

# %%
devices = pd.read_csv(os.path.join(data_path, "device_count.csv"))

# %%
print(devices.shape)
devices.columns
# Out:
# (639838, 4)
# Index(['Time', 'No. of Devices', 'Measurement', 'ID'], dtype='object')

# %%
print(f"Date range: {devices.Time.min()} - {devices.Time.max()}")
# Out:
# Date range: 2022-06-30 19:00:58.793308-05:00 - 2022-07-31 18:57:29.838862-05:00

# %%
print(devices.Measurement.unique())
print("Device count summaries\n", devices["No. of Devices"].describe())
print("Number of devices: ", devices.ID.nunique())
devices.groupby(["ID"]).size().reset_index()
# Out:
# ['connected_devices_arp']
# Device count summaries
#  count   639838.00000
# mean         9.29263
# std          7.60706
# min          1.00000
# 25%          4.00000
# 50%          7.00000
# 75%         11.00000
# max         42.00000
# Name: No. of Devices, dtype: float64
# Number of devices:  86
#                            ID     0
# 0   nm-mngd-20210518-005bb669  7945
# 1   nm-mngd-20210518-0ca06c37  7900
# 2   nm-mngd-20210518-19941862  8924
# 3   nm-mngd-20210518-28abe768  8862
# 4   nm-mngd-20210518-c22d980b  8885
# 5   nm-mngd-20210518-f2242dfd  8924
# 6   nm-mngd-20210519-84594993  8925
# 7   nm-mngd-20210519-ee6bcbb8  8926
# 8   nm-mngd-20210623-1b49a7fa  8757
# 9   nm-mngd-20210915-0e5a8b9f   280
# 10  nm-mngd-20210915-21cdf51f  8914
# 11  nm-mngd-20210915-3fb6ba43  8921
# 12  nm-mngd-20210915-4489c8bd  8919
# 13  nm-mngd-20210915-5042f35e  8871
# 14  nm-mngd-20210915-612a3db3   685
# 15  nm-mngd-20210915-774040d7  8915
# 16  nm-mngd-20210915-89e40819  8927
# 17  nm-mngd-20210915-8bb64c9a  2256
# 18  nm-mngd-20210915-8d4ba8df  2284
# 19  nm-mngd-20210915-8dd84998  8806
# 20  nm-mngd-20210915-8edface4  8917
# 21  nm-mngd-20210915-9db171c4  2832
# 22  nm-mngd-20210915-a2352afe  2242
# 23  nm-mngd-20210915-a64ec38c  8870
# 24  nm-mngd-20210915-cf796bf1   478
