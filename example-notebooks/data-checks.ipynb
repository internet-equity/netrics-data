# %%
import pandas as pd
import os

data_path = "../data/netrics/2022-09-01-2022-10-01"

# %%
speedtests = pd.read_csv(os.path.join(data_path, "speedtest.csv"))

# %%
print(speedtests.shape)
speedtests.columns
# Out:
# (76279, 5)
# Index(['Time', 'Direction', 'Tool', 'Speed', 'ID'], dtype='object')

# %%
print(f"Date range: {speedtests.Time.min()} - {speedtests.Time.max()}")
# Out:
# Date range: 2022-08-31 19:00:43.375767-05:00 - 2022-09-30 18:59:09.543948-05:00

# %%
pd.options.display.max_rows = 300
print(speedtests.Direction.unique())
print(speedtests.Tool.unique())
print("Speed summaries\n", speedtests.Speed.describe())
print("Number of devices: ", speedtests.ID.nunique())
speedtests.groupby(["ID", "Tool"]).size().reset_index()
# Out:
# ['download' 'upload']
# ['iPerf3 (TCP)' 'iPerf3 (UDP)' 'ndt7' 'ookla']
# Speed summaries
#  count     76279.000000
# mean        336.618732
# std        1974.361455
# min     -529290.791256
# 25%          24.253366
# 50%         117.919392
# 75%         718.933827
# max         956.466204
# Name: Speed, dtype: float64
# Number of devices:  78
#                             ID          Tool     0
# 0    nm-mngd-20210511-9d9824d4  iPerf3 (TCP)    52
# 1    nm-mngd-20210511-9d9824d4  iPerf3 (UDP)   104
# 2    nm-mngd-20210511-9d9824d4          ndt7    82
# 3    nm-mngd-20210511-9d9824d4         ookla    82
# 4    nm-mngd-20210518-005bb669  iPerf3 (TCP)    58
# ..                         ...           ...   ...
# 301  nm-mngd-20220628-07c02d28  iPerf3 (UDP)    91
# 302  nm-mngd-20220628-07c02d28          ndt7  2788
# 303  nm-mngd-20220628-07c02d28         ookla  2782
# 304  nm-mngd-20220914-164dbe45          ndt7     2
# 305  nm-mngd-20220914-9d4c196c          ndt7     2
#
# [306 rows x 3 columns]

# %%
ping_latency = pd.read_csv(os.path.join(data_path, "ping_latency.csv"))

# %%
print(ping_latency.shape)
ping_latency.columns
# Out:
# (6994009, 6)
# Index(['Time', 'RTT', 'Measurement', 'ID', 'Destination', 'Method'], dtype='object')

# %%
print(f"Date range: {ping_latency.Time.min()} - {ping_latency.Time.max()}")
# Out:
# Date range: 2022-08-31 19:00:04.657174-05:00 - 2022-09-30 18:59:09.543948-05:00

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)
print(ping_latency.Measurement.unique())
print(ping_latency.Destination.unique())
print(ping_latency.Method.unique())
print("Ping latency summaries\n", ping_latency.RTT.describe())
print("Number of devices: ", ping_latency.ID.nunique())
ping_latency.groupby(["ID"]).size().reset_index()
# Out:
# ['ping_latency' 'last_mile_rtt']
# ['Atlanta' 'Last Mile' 'Denver' 'Washington' 'amazon' 'facebook' 'google'
#  'suntimes' 'tribune' 'uchicago' 'wikipedia' 'youtube']
# ['Avg' 'Min']
# Ping latency summaries
#  count   6994009.00000
# mean         20.51619
# std          41.43355
# min           0.40700
# 25%           8.01500
# 50%          12.32600
# 75%          27.75600
# max        4979.83200
# Name: RTT, dtype: float64
# Number of devices:  78
#                            ID       0
# 0   nm-mngd-20210511-9d9824d4  103872
# 63  nm-mngd-20220505-30005b68   43898
# 64  nm-mngd-20220505-3740f507   83982
# 65  nm-mngd-20220505-4d0b6753    1982
# 66  nm-mngd-20220505-7db0ce31  114353
# 67  nm-mngd-20220505-a8149041  104633
# 68  nm-mngd-20220505-dcd76b53  103926
# 69  nm-mngd-20220506-2f996174  101038
# 70  nm-mngd-20220506-3809e1bb  103978
# 71  nm-mngd-20220506-8652c367  103657
# 72  nm-mngd-20220506-98c85a91  104073
# 73  nm-mngd-20220621-eb793ac0  107584
# 74  nm-mngd-20220623-59224a4d  104693
# 75  nm-mngd-20220628-07c02d28  116227
# 76  nm-mngd-20220914-164dbe45      15
# 77  nm-mngd-20220914-9d4c196c      15

# %%
lul = pd.read_csv(os.path.join(data_path, "lul.csv"))

# %%
print(lul.shape)
lul.columns
# Out:
# (26029, 7)
# Index(['Time', 'RTT', 'Measurement', 'ID', 'Protocol', 'Direction',
#        'Destination'],
#       dtype='object')

# %%
print(f"Date range: {lul.Time.min()} - {lul.Time.max()}")
# Out:
# Date range: 2022-08-31 19:00:43.375767-05:00 - 2022-09-30 18:51:05.260191-05:00

# %%
print(lul.Measurement.unique())
print(lul.Direction.unique())
print(lul.Protocol.unique())
print(lul.Destination.unique())
print("LUL summaries\n", lul.RTT.describe())
print("Number of devices: ", lul.ID.nunique())
lul.groupby(["ID"]).size().reset_index()
# Out:
# ['oplat']
# ['upload' 'download']
# ['icmp' 'tcp']
# ['abbott.cs.uchicago.edu']
# LUL summaries
#  count   26029.00000
# mean      115.60766
# std       331.08285
# min        -0.00000
# 25%        17.58950
# 50%        38.09371
# 75%        99.70373
# max      5748.61224
# Name: RTT, dtype: float64
# Number of devices:  76
#                            ID     0
# 0   nm-mngd-20210511-9d9824d4    75
# 1   nm-mngd-20210518-005bb669    88
# 2   nm-mngd-20210518-0ca06c37  4185
# 3   nm-mngd-20210518-19941862   103
# 4   nm-mngd-20210518-28abe768   230
# 5   nm-mngd-20210518-a312bf95   973
# 6   nm-mngd-20210518-c22d980b   757
# 7   nm-mngd-20210518-f2242dfd  1021
# 8   nm-mngd-20210519-84594993    25
# 9   nm-mngd-20210519-ee6bcbb8   100
# 10  nm-mngd-20210915-21cdf51f   189
# 11  nm-mngd-20210915-3fb6ba43   329
# 12  nm-mngd-20210915-4489c8bd    35
# 13  nm-mngd-20210915-5042f35e   151
# 14  nm-mngd-20210915-612a3db3   183
# 15  nm-mngd-20210915-774040d7   101
# 16  nm-mngd-20210915-89e40819   389
# 17  nm-mngd-20210915-8bb64c9a   319
# 18  nm-mngd-20210915-8d4ba8df   135
# 19  nm-mngd-20210915-8dd84998   127
# 20  nm-mngd-20210915-8edface4   295
# 21  nm-mngd-20210915-9db171c4   128
# 22  nm-mngd-20210915-a2352afe   360
# 23  nm-mngd-20210915-a64ec38c   171
# 24  nm-mngd-20210916-d58b5bfc    88
# 25  nm-mngd-20210923-074c086d   291
# 26  nm-mngd-20210924-1ca7f852   131
# 27  nm-mngd-20210924-48964f71   458
# 28  nm-mngd-20210924-77f105f0   381
# 29  nm-mngd-20210924-872de77e    96
# 30  nm-mngd-20210924-8d1e98ab   323
# 31  nm-mngd-20210924-a97dceb2   102
# 32  nm-mngd-20210924-cbe578f4   401
# 33  nm-mngd-20210924-fad61185   494
# 34  nm-mngd-20210927-04dc925c   400
# 35  nm-mngd-20210927-145c392b   129
# 36  nm-mngd-20210927-178debb9   201
# 37  nm-mngd-20210927-1a4f71d4   393
# 38  nm-mngd-20210927-1aaa32b5   237
# 39  nm-mngd-20210927-3f24e5b4   461
# 40  nm-mngd-20210927-4a1de38c   124
# 41  nm-mngd-20210927-4def23bd   278
# 42  nm-mngd-20210927-8da43959    89
# 43  nm-mngd-20210927-9044c591   120
# 44  nm-mngd-20210927-cc1bdfb9   118
# 45  nm-mngd-20210927-d8cfa28a   393
# 46  nm-mngd-20210927-f4ccde6b   242
# 47  nm-mngd-20210927-f531ff46    75
# 48  nm-mngd-20211006-ce55f0f2   104
# 49  nm-mngd-20211210-0e99d30d   112
# 50  nm-mngd-20220217-066fd54b   166
# 51  nm-mngd-20220217-153d4573    61
# 52  nm-mngd-20220217-23cbb217   120
# 53  nm-mngd-20220217-47373932   171
# 54  nm-mngd-20220217-9da01799    90
# 55  nm-mngd-20220217-d4ed546b    97
# 56  nm-mngd-20220218-178af0c4   453
# 57  nm-mngd-20220218-486047bf   111
# 58  nm-mngd-20220218-77d108b6   539
# 59  nm-mngd-20220221-bffd128d   617
# 60  nm-mngd-20220224-e5552881   422
# 61  nm-mngd-20220301-fac88cb2    81
# 62  nm-mngd-20220505-23cccfed   560
# 63  nm-mngd-20220505-30005b68   160
# 64  nm-mngd-20220505-3740f507    75
# 65  nm-mngd-20220505-4d0b6753    36
# 66  nm-mngd-20220505-7db0ce31    28
# 67  nm-mngd-20220505-a8149041   135
# 68  nm-mngd-20220505-dcd76b53    42
# 69  nm-mngd-20220506-2f996174   115
# 70  nm-mngd-20220506-3809e1bb   121
# 71  nm-mngd-20220506-8652c367   298
# 72  nm-mngd-20220506-98c85a91   504
# 73  nm-mngd-20220621-eb793ac0    83
# 74  nm-mngd-20220623-59224a4d   104
# 75  nm-mngd-20220628-07c02d28  4130

# %%
lan_bw = pd.read_csv(os.path.join(data_path, "lan_bw.csv"))

# %%
print(lan_bw.shape)
lan_bw.columns
# Out:
# (1715, 5)
# Index(['Time', 'Speed', 'Measurement', 'ID', 'Origin'], dtype='object')

# %%
print(f"Date range: {lan_bw.Time.min()} - {lan_bw.Time.max()}")
# Out:
# Date range: 2022-08-31 19:05:27-05:00 - 2022-09-30 18:24:29-05:00

# %%
print(lan_bw.Measurement.unique())
print(lan_bw.Origin.unique())
print("Speed summaries\n", lan_bw.Speed.describe())
print("Number of devices: ", lan_bw.ID.nunique())
lan_bw.groupby(["ID"]).size().reset_index()
# Out:
# ['lan_bw_client_mbps' 'lan_bw_server_mbps']
# ['Client' 'Netrics']
# Speed summaries
#  count   1715.00000
# mean     262.26142
# std      209.28010
# min        0.55723
# 25%       93.66444
# 50%      199.35643
# 75%      392.52261
# max      927.58398
# Name: Speed, dtype: float64
# Number of devices:  24
#                            ID    0
# 0   nm-mngd-20210518-19941862  155
# 1   nm-mngd-20210518-28abe768   60
# 2   nm-mngd-20210518-c22d980b   17
# 3   nm-mngd-20210518-f2242dfd  210
# 4   nm-mngd-20210915-3fb6ba43   42
# 5   nm-mngd-20210915-4489c8bd  157
# 6   nm-mngd-20210915-612a3db3   84
# 7   nm-mngd-20210923-074c086d   54
# 8   nm-mngd-20210924-1ca7f852   12
# 9   nm-mngd-20210924-48964f71  140
# 10  nm-mngd-20210924-872de77e   23
# 11  nm-mngd-20210924-8d1e98ab   58
# 12  nm-mngd-20210927-3f24e5b4   17
# 13  nm-mngd-20210927-d8cfa28a  104
# 14  nm-mngd-20210927-f4ccde6b   31
# 15  nm-mngd-20211210-0e99d30d   12
# 16  nm-mngd-20220217-066fd54b  137
# 17  nm-mngd-20220217-23cbb217   85
# 18  nm-mngd-20220217-47373932  119
# 19  nm-mngd-20220217-d4ed546b    6
# 20  nm-mngd-20220218-486047bf    2
# 21  nm-mngd-20220505-23cccfed  102
# 22  nm-mngd-20220505-a8149041    9
# 23  nm-mngd-20220505-dcd76b53   79

# %%
hops = pd.read_csv(os.path.join(data_path, "hops_to_google.csv"))

# %%
print(hops.shape)
hops.columns
# Out:
# (571622, 4)
# Index(['Time', 'Hops', 'Measurement', 'ID'], dtype='object')

# %%
print(f"Date range: {hops.Time.min()} - {hops.Time.max()}")
# Out:
# Date range: 2022-08-31 19:00:55.214683-05:00 - 2022-09-30 18:58:37.533637-05:00

# %%
print(hops.Measurement.unique())
print("Hops summaries\n", hops.Hops.describe())
print("Number of devices: ", hops.ID.nunique())
hops.groupby(["ID"]).size().reset_index()
# Out:
# ['hops_to_google']
# Hops summaries
#  count   571622.00000
# mean        11.62165
# std          2.84531
# min          1.00000
# 25%          9.00000
# 50%         12.00000
# 75%         13.00000
# max         20.00000
# Name: Hops, dtype: float64
# Number of devices:  78
#                            ID     0
# 0   nm-mngd-20210511-9d9824d4  8622
# 1   nm-mngd-20210518-005bb669  5049
# 2   nm-mngd-20210518-0ca06c37  8594
# 3   nm-mngd-20210518-19941862  8626
# 4   nm-mngd-20210518-28abe768  8632
# 5   nm-mngd-20210518-a312bf95  7929
# 6   nm-mngd-20210518-c22d980b  8192
# 7   nm-mngd-20210518-f2242dfd  8630
# 8   nm-mngd-20210519-84594993  8634
# 9   nm-mngd-20210519-ee6bcbb8  8214
# 10  nm-mngd-20210915-21cdf51f  8637
# 11  nm-mngd-20210915-3fb6ba43  8640
# 12  nm-mngd-20210915-4489c8bd  8639
# 13  nm-mngd-20210915-5042f35e  8460
# 14  nm-mngd-20210915-612a3db3  8634
# 15  nm-mngd-20210915-774040d7  8612
# 16  nm-mngd-20210915-89e40819  8640
# 17  nm-mngd-20210915-8bb64c9a  2163
# 18  nm-mngd-20210915-8d4ba8df  2171
# 19  nm-mngd-20210915-8dd84998  8577
# 20  nm-mngd-20210915-8edface4  8640
# 21  nm-mngd-20210915-9db171c4  1816
# 22  nm-mngd-20210915-a2352afe  2140
# 23  nm-mngd-20210915-a64ec38c  8634
# 24  nm-mngd-20210916-d58b5bfc  8560
# 25  nm-mngd-20210923-074c086d  8542
# 26  nm-mngd-20210924-1ca7f852  8492
# 27  nm-mngd-20210924-48964f71  8639
# 28  nm-mngd-20210924-77f105f0  8420
# 29  nm-mngd-20210924-872de77e  8617
# 30  nm-mngd-20210924-8d1e98ab  2074
# 31  nm-mngd-20210924-a97dceb2  2089
# 32  nm-mngd-20210924-cbe578f4  8615
# 33  nm-mngd-20210924-fad61185  8630
# 34  nm-mngd-20210927-04dc925c  8633
# 35  nm-mngd-20210927-145c392b  8639
# 36  nm-mngd-20210927-178debb9  8639
# 37  nm-mngd-20210927-1a4f71d4  8632
# 38  nm-mngd-20210927-1aaa32b5  2252
# 39  nm-mngd-20210927-3f24e5b4  8635
# 40  nm-mngd-20210927-4a1de38c  8631
# 41  nm-mngd-20210927-4def23bd  8629
# 42  nm-mngd-20210927-8da43959  8593
# 43  nm-mngd-20210927-9044c591  8628
# 44  nm-mngd-20210927-cc1bdfb9  8636
# 45  nm-mngd-20210927-d8cfa28a  8499
# 46  nm-mngd-20210927-f4ccde6b  8353
# 47  nm-mngd-20210927-f531ff46  8628
# 48  nm-mngd-20211006-ce55f0f2  6841
# 49  nm-mngd-20211210-0e99d30d  8555
# 50  nm-mngd-20220217-066fd54b  8588
# 51  nm-mngd-20220217-153d4573  8612
# 52  nm-mngd-20220217-23cbb217  8613
# 53  nm-mngd-20220217-47373932  2113
# 54  nm-mngd-20220217-9da01799  3872
# 55  nm-mngd-20220217-d4ed546b  8638
# 56  nm-mngd-20220218-178af0c4  8622
# 57  nm-mngd-20220218-486047bf  8520
# 58  nm-mngd-20220218-77d108b6  8572
# 59  nm-mngd-20220221-bffd128d  8636
# 60  nm-mngd-20220224-e5552881  8353
# 61  nm-mngd-20220301-fac88cb2  2918
# 62  nm-mngd-20220505-23cccfed  8534
# 63  nm-mngd-20220505-30005b68  3292
# 64  nm-mngd-20220505-3740f507  7070
# 65  nm-mngd-20220505-4d0b6753  2918
# 66  nm-mngd-20220505-7db0ce31  8593
# 67  nm-mngd-20220505-a8149041  8639
# 68  nm-mngd-20220505-dcd76b53  8565
# 69  nm-mngd-20220506-2f996174  8588
# 70  nm-mngd-20220506-3809e1bb  8623
# 71  nm-mngd-20220506-8652c367  8591
# 72  nm-mngd-20220506-98c85a91  8629
# 73  nm-mngd-20220621-eb793ac0  8640
# 74  nm-mngd-20220623-59224a4d  8639
# 75  nm-mngd-20220628-07c02d28  8616
# 76  nm-mngd-20220914-164dbe45     1
# 77  nm-mngd-20220914-9d4c196c     1

# %%
dns = pd.read_csv(os.path.join(data_path, "dns_latency.csv"))

# %%
print(dns.shape)
dns.columns
# Out:
# (1143312, 5)
# Index(['Time', 'Query Time', 'Measurement', 'ID', 'Type'], dtype='object')

# %%
print(f"Date range: {dns.Time.min()} - {dns.Time.max()}")
# Out:
# Date range: 2022-08-31 19:00:55.214683-05:00 - 2022-09-30 18:58:37.533637-05:00

# %%
print(dns.Measurement.unique())
print(dns.Type.unique())
print("DNS summaries\n", dns["Query Time"].describe())
print("Number of devices: ", dns.ID.nunique())
dns.groupby(["ID"]).size().reset_index()
# Out:
# ['dns_latency']
# ['Avg' 'Max']
# DNS summaries
#  count   1143312.00000
# mean         65.99830
# std         231.00199
# min           0.75000
# 25%          25.00000
# 50%          39.00000
# 75%          55.00000
# max        4999.00000
# Name: Query Time, dtype: float64
# Number of devices:  78
#                            ID      0
# 0   nm-mngd-20210511-9d9824d4  17244
# 1   nm-mngd-20210518-005bb669  10102
# 2   nm-mngd-20210518-0ca06c37  17188
# 3   nm-mngd-20210518-19941862  17252
# 4   nm-mngd-20210518-28abe768  17266
# 5   nm-mngd-20210518-a312bf95  15858
# 6   nm-mngd-20210518-c22d980b  16384
# 7   nm-mngd-20210518-f2242dfd  17260
# 8   nm-mngd-20210519-84594993  17268
# 9   nm-mngd-20210519-ee6bcbb8  16482
# 10  nm-mngd-20210915-21cdf51f  17274
# 11  nm-mngd-20210915-3fb6ba43  17280
# 12  nm-mngd-20210915-4489c8bd  17278
# 13  nm-mngd-20210915-5042f35e  16920
# 14  nm-mngd-20210915-612a3db3  17268
# 15  nm-mngd-20210915-774040d7  17224
# 16  nm-mngd-20210915-89e40819  17280
# 17  nm-mngd-20210915-8bb64c9a   4326
# 18  nm-mngd-20210915-8d4ba8df   4342
# 19  nm-mngd-20210915-8dd84998  17154
# 20  nm-mngd-20210915-8edface4  17280
# 21  nm-mngd-20210915-9db171c4   3632
# 22  nm-mngd-20210915-a2352afe   4280
# 23  nm-mngd-20210915-a64ec38c  17268
# 24  nm-mngd-20210916-d58b5bfc  17120
# 25  nm-mngd-20210923-074c086d  17084
# 26  nm-mngd-20210924-1ca7f852  16984
# 27  nm-mngd-20210924-48964f71  17278
# 28  nm-mngd-20210924-77f105f0  16840
# 29  nm-mngd-20210924-872de77e  17234
# 30  nm-mngd-20210924-8d1e98ab   4148
# 31  nm-mngd-20210924-a97dceb2   4178
# 32  nm-mngd-20210924-cbe578f4  17230
# 33  nm-mngd-20210924-fad61185  17260
# 34  nm-mngd-20210927-04dc925c  17266
# 35  nm-mngd-20210927-145c392b  17278
# 36  nm-mngd-20210927-178debb9  17278
# 37  nm-mngd-20210927-1a4f71d4  17264
# 38  nm-mngd-20210927-1aaa32b5   4504
# 39  nm-mngd-20210927-3f24e5b4  17270
# 40  nm-mngd-20210927-4a1de38c  17262
# 41  nm-mngd-20210927-4def23bd  17258
# 42  nm-mngd-20210927-8da43959  17186
# 43  nm-mngd-20210927-9044c591  17256
# 44  nm-mngd-20210927-cc1bdfb9  17272
# 45  nm-mngd-20210927-d8cfa28a  16998
# 46  nm-mngd-20210927-f4ccde6b  16706
# 47  nm-mngd-20210927-f531ff46  17256
# 48  nm-mngd-20211006-ce55f0f2  13682
# 49  nm-mngd-20211210-0e99d30d  17112
# 50  nm-mngd-20220217-066fd54b  17176
# 51  nm-mngd-20220217-153d4573  17224
# 52  nm-mngd-20220217-23cbb217  17226
# 53  nm-mngd-20220217-47373932   4226
# 54  nm-mngd-20220217-9da01799   7744
# 55  nm-mngd-20220217-d4ed546b  17276
# 56  nm-mngd-20220218-178af0c4  17244
# 57  nm-mngd-20220218-486047bf  17040
# 58  nm-mngd-20220218-77d108b6  17144
# 59  nm-mngd-20220221-bffd128d  17272
# 60  nm-mngd-20220224-e5552881  16706
# 61  nm-mngd-20220301-fac88cb2   5836
# 62  nm-mngd-20220505-23cccfed  17068
# 63  nm-mngd-20220505-30005b68   6584
# 64  nm-mngd-20220505-3740f507  14140
# 65  nm-mngd-20220505-4d0b6753   5836
# 66  nm-mngd-20220505-7db0ce31  17186
# 67  nm-mngd-20220505-a8149041  17278
# 68  nm-mngd-20220505-dcd76b53  17130
# 69  nm-mngd-20220506-2f996174  17182
# 70  nm-mngd-20220506-3809e1bb  17246
# 71  nm-mngd-20220506-8652c367  17182
# 72  nm-mngd-20220506-98c85a91  17258
# 73  nm-mngd-20220621-eb793ac0  17280
# 74  nm-mngd-20220623-59224a4d  17278
# 75  nm-mngd-20220628-07c02d28  17232
# 76  nm-mngd-20220914-164dbe45      2
# 77  nm-mngd-20220914-9d4c196c      2

# %%
devices = pd.read_csv(os.path.join(data_path, "device_count.csv"))

# %%
print(devices.shape)
devices.columns
# Out:
# (566150, 4)
# Index(['Time', 'No. of Devices', 'Measurement', 'ID'], dtype='object')

# %%
print(f"Date range: {devices.Time.min()} - {devices.Time.max()}")
# Out:
# Date range: 2022-08-31 19:00:03.181160-05:00 - 2022-09-30 18:58:37.533637-05:00

# %%
print(devices.Measurement.unique())
print("Device count summaries\n", devices["No. of Devices"].describe())
print("Number of devices: ", devices.ID.nunique())
devices.groupby(["ID"]).size().reset_index()
# Out:
# ['connected_devices_arp']
# Device count summaries
#  count   566150.00000
# mean         9.73236
# std          7.79500
# min          1.00000
# 25%          5.00000
# 50%          7.00000
# 75%         11.00000
# max         41.00000
# Name: No. of Devices, dtype: float64
# Number of devices:  77
#                            ID     0
# 0   nm-mngd-20210511-9d9824d4  8628
# 1   nm-mngd-20210518-005bb669  5049
# 2   nm-mngd-20210518-0ca06c37  8594
# 3   nm-mngd-20210518-19941862  8626
# 4   nm-mngd-20210518-28abe768  8638
# 5   nm-mngd-20210518-c22d980b  8192
# 6   nm-mngd-20210518-f2242dfd  8634
# 7   nm-mngd-20210519-84594993  8636
# 8   nm-mngd-20210519-ee6bcbb8  8244
# 9   nm-mngd-20210915-21cdf51f  8638
# 10  nm-mngd-20210915-3fb6ba43  8640
# 11  nm-mngd-20210915-4489c8bd  8639
# 12  nm-mngd-20210915-5042f35e  8631
# 13  nm-mngd-20210915-612a3db3  8634
# 14  nm-mngd-20210915-774040d7  8632
