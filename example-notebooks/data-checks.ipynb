# %%
import pandas as pd
import os

data_path = "../data/netrics/2022-08-01-2022-09-01"

# %%
speedtests = pd.read_csv(os.path.join(data_path, "speedtest.csv"))

# %%
print(speedtests.shape)
speedtests.columns
# Out:
# (81449, 5)
# Index(['Time', 'Direction', 'Tool', 'Speed', 'ID'], dtype='object')

# %%
print(f"Date range: {speedtests.Time.min()} - {speedtests.Time.max()}")
# Out:
# Date range: 2022-07-31 19:02:12.427664-05:00 - 2022-08-31 18:58:42.055683-05:00

# %%
pd.options.display.max_rows = 300
print(speedtests.Direction.unique())
print(speedtests.Tool.unique())
print("Speed summaries\n", speedtests.Speed.describe())
print("Number of devices: ", speedtests.ID.nunique())
speedtests.groupby(["ID", "Tool"]).size().reset_index()
# Out:
# ['download' 'upload']
# ['iPerf3 (TCP)' 'iPerf3 (UDP)' 'ndt7' 'ookla']
# Speed summaries
#  count    81449.000000
# mean       337.407590
# std        360.464049
# min          0.000000
# 25%         23.989165
# 50%        116.426672
# 75%        721.281687
# max        956.570139
# Name: Speed, dtype: float64
# Number of devices:  84
#                             ID          Tool     0
# 0    nm-mngd-20210511-9d9824d4  iPerf3 (TCP)     6
# 1    nm-mngd-20210511-9d9824d4  iPerf3 (UDP)    12
# 2    nm-mngd-20210511-9d9824d4          ndt7    20
# 3    nm-mngd-20210511-9d9824d4         ookla    18
# 4    nm-mngd-20210518-005bb669  iPerf3 (TCP)    60
# ..                         ...           ...   ...
# 331  nm-mngd-20220623-59224a4d         ookla    94
# 332  nm-mngd-20220628-07c02d28  iPerf3 (TCP)  2755
# 333  nm-mngd-20220628-07c02d28  iPerf3 (UDP)    78
# 334  nm-mngd-20220628-07c02d28          ndt7  2802
# 335  nm-mngd-20220628-07c02d28         ookla  2802
#
# [336 rows x 3 columns]

# %%
ping_latency = pd.read_csv(os.path.join(data_path, "ping_latency.csv"))

# %%
print(ping_latency.shape)
ping_latency.columns
# Out:
# (7959576, 6)
# Index(['Time', 'RTT', 'Measurement', 'ID', 'Destination', 'Method'], dtype='object')

# %%
print(f"Date range: {ping_latency.Time.min()} - {ping_latency.Time.max()}")
# Out:
# Date range: 2022-07-31 19:00:04.726134-05:00 - 2022-08-31 18:59:04.311035-05:00

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)
print(ping_latency.Measurement.unique())
print(ping_latency.Destination.unique())
print(ping_latency.Method.unique())
print("Ping latency summaries\n", ping_latency.RTT.describe())
print("Number of devices: ", ping_latency.ID.nunique())
ping_latency.groupby(["ID"]).size().reset_index()
# Out:
# ['ping_latency' 'last_mile_rtt']
# ['Atlanta' 'Last Mile' 'Denver' 'Washington' 'amazon' 'facebook' 'google'
#  'suntimes' 'tribune' 'uchicago' 'wikipedia' 'youtube']
# ['Avg' 'Min']
# Ping latency summaries
#  count   7959576.00000
# mean         20.11651
# std          38.02959
# min           0.25100
# 25%           8.09600
# 50%          12.07200
# 75%          27.12800
# max        4997.03100
# Name: RTT, dtype: float64
# Number of devices:  84
#                            ID       0
# 0   nm-mngd-20210511-9d9824d4   22732
# 1   nm-mngd-20210518-005bb669  102551
# 2   nm-mngd-20210518-0ca06c37  115613
# 3   nm-mngd-20210518-19941862  114839
# 4   nm-mngd-20210518-28abe768  114865
# 71  nm-mngd-20220505-7db0ce31  106223
# 72  nm-mngd-20220505-a8149041  119020
# 73  nm-mngd-20220505-dcd76b53  117996
# 74  nm-mngd-20220506-2f996174  118951
# 75  nm-mngd-20220506-3809e1bb  118979
# 76  nm-mngd-20220506-8652c367  118768
# 77  nm-mngd-20220506-98c85a91  118686
# 78  nm-mngd-20220621-5913a3d5   99089
# 79  nm-mngd-20220621-eb793ac0  119026
# 80  nm-mngd-20220622-299d1347    6720
# 81  nm-mngd-20220622-a9810b6f   29332
# 82  nm-mngd-20220623-59224a4d  119012
# 83  nm-mngd-20220628-07c02d28  115634

# %%
lul = pd.read_csv(os.path.join(data_path, "lul.csv"))

# %%
print(lul.shape)
lul.columns
# Out:
# (27317, 7)
# Index(['Time', 'RTT', 'Measurement', 'ID', 'Protocol', 'Direction',
#        'Destination'],
#       dtype='object')

# %%
print(f"Date range: {lul.Time.min()} - {lul.Time.max()}")
# Out:
# Date range: 2022-07-31 19:02:23.539282-05:00 - 2022-08-31 18:57:14.103175-05:00

# %%
print(lul.Measurement.unique())
print(lul.Direction.unique())
print(lul.Protocol.unique())
print(lul.Destination.unique())
print("LUL summaries\n", lul.RTT.describe())
print("Number of devices: ", lul.ID.nunique())
lul.groupby(["ID"]).size().reset_index()
# Out:
# ['oplat']
# ['upload' 'download']
# ['icmp' 'tcp']
# ['abbott.cs.uchicago.edu']
# LUL summaries
#  count   27317.00000
# mean      112.47628
# std       329.41039
# min        -0.00000
# 25%        17.39945
# 50%        39.32705
# 75%       113.55433
# max      5834.58992
# Name: RTT, dtype: float64
# Number of devices:  84
#                            ID     0
# 0   nm-mngd-20210511-9d9824d4     7
# 1   nm-mngd-20210518-005bb669    90
# 2   nm-mngd-20210518-0ca06c37  4139
# 3   nm-mngd-20210518-19941862    69
# 4   nm-mngd-20210518-28abe768   228
# 5   nm-mngd-20210518-a312bf95   961
# 6   nm-mngd-20210518-c22d980b   375
# 7   nm-mngd-20210518-f2242dfd   993
# 8   nm-mngd-20210519-84594993    39
# 9   nm-mngd-20210519-ee6bcbb8    96
# 10  nm-mngd-20210623-1b49a7fa    52
# 11  nm-mngd-20210915-21cdf51f   144
# 12  nm-mngd-20210915-3fb6ba43   290
# 13  nm-mngd-20210915-4489c8bd    40
# 14  nm-mngd-20210915-5042f35e   193
# 15  nm-mngd-20210915-612a3db3    54
# 16  nm-mngd-20210915-774040d7   114
# 17  nm-mngd-20210915-89e40819   530
# 18  nm-mngd-20210915-8bb64c9a   359
# 19  nm-mngd-20210915-8d4ba8df   116
# 20  nm-mngd-20210915-8dd84998   130
# 21  nm-mngd-20210915-8edface4   445
# 22  nm-mngd-20210915-9db171c4   143
# 23  nm-mngd-20210915-a2352afe   329
# 24  nm-mngd-20210915-a64ec38c   192
# 25  nm-mngd-20210915-d5f18da9    66
# 26  nm-mngd-20210915-f4b4a69b   113
# 27  nm-mngd-20210916-d58b5bfc   114
# 28  nm-mngd-20210923-074c086d   290
# 29  nm-mngd-20210924-1ca7f852   125
# 30  nm-mngd-20210924-48964f71   460
# 31  nm-mngd-20210924-77f105f0   392
# 32  nm-mngd-20210924-872de77e    78
# 33  nm-mngd-20210924-8d1e98ab   285
# 34  nm-mngd-20210924-a97dceb2   114
# 35  nm-mngd-20210924-cbe578f4   417
# 36  nm-mngd-20210924-fad61185    27
# 37  nm-mngd-20210927-04dc925c   427
# 38  nm-mngd-20210927-145c392b   121
# 39  nm-mngd-20210927-178debb9   355
# 40  nm-mngd-20210927-1a4f71d4   454
# 41  nm-mngd-20210927-1aaa32b5   357
# 42  nm-mngd-20210927-1b5896d3    53
# 43  nm-mngd-20210927-3f24e5b4   494
# 44  nm-mngd-20210927-4a1de38c   173
# 45  nm-mngd-20210927-4def23bd   288
# 46  nm-mngd-20210927-8da43959   126
# 47  nm-mngd-20210927-9044c591   123
# 48  nm-mngd-20210927-cc1bdfb9   183
# 49  nm-mngd-20210927-d8cfa28a   302
# 50  nm-mngd-20210927-f4ccde6b   255
# 51  nm-mngd-20210927-f531ff46    80
# 52  nm-mngd-20211006-ce55f0f2   145
# 53  nm-mngd-20211210-0e99d30d   117
# 54  nm-mngd-20220217-066fd54b   171
# 55  nm-mngd-20220217-153d4573    67
# 56  nm-mngd-20220217-23cbb217   140
# 57  nm-mngd-20220217-47373932   214
# 58  nm-mngd-20220217-9da01799    89
# 59  nm-mngd-20220217-d4ed546b   106
# 60  nm-mngd-20220218-178af0c4   477
# 61  nm-mngd-20220218-486047bf   141
# 62  nm-mngd-20220218-77d108b6   493
# 63  nm-mngd-20220221-bffd128d   549
# 64  nm-mngd-20220224-e5552881   399
# 65  nm-mngd-20220301-fac88cb2   413
# 66  nm-mngd-20220505-13e9adcd   467
# 67  nm-mngd-20220505-23cccfed   482
# 68  nm-mngd-20220505-30005b68   440
# 69  nm-mngd-20220505-3740f507    80
# 70  nm-mngd-20220505-4d0b6753    60
# 71  nm-mngd-20220505-7db0ce31    63
# 72  nm-mngd-20220505-a8149041   134
# 73  nm-mngd-20220505-dcd76b53    76
# 74  nm-mngd-20220506-2f996174   157
# 75  nm-mngd-20220506-3809e1bb   108
# 76  nm-mngd-20220506-8652c367   237
# 77  nm-mngd-20220506-98c85a91   458
# 78  nm-mngd-20220621-5913a3d5   133
# 79  nm-mngd-20220621-eb793ac0   133
# 80  nm-mngd-20220622-299d1347    10
# 81  nm-mngd-20220622-a9810b6f    80
# 82  nm-mngd-20220623-59224a4d   143
# 83  nm-mngd-20220628-07c02d28  4135

# %%
lan_bw = pd.read_csv(os.path.join(data_path, "lan_bw.csv"))

# %%
print(lan_bw.shape)
lan_bw.columns
# Out:
# (2356, 5)
# Index(['Time', 'Speed', 'Measurement', 'ID', 'Origin'], dtype='object')

# %%
print(f"Date range: {lan_bw.Time.min()} - {lan_bw.Time.max()}")
# Out:
# Date range: 2022-07-31 20:47:54-05:00 - 2022-08-31 17:40:04-05:00

# %%
print(lan_bw.Measurement.unique())
print(lan_bw.Origin.unique())
print("Speed summaries\n", lan_bw.Speed.describe())
print("Number of devices: ", lan_bw.ID.nunique())
lan_bw.groupby(["ID"]).size().reset_index()
# Out:
# ['lan_bw_client_mbps' 'lan_bw_server_mbps']
# ['Client' 'Netrics']
# Speed summaries
#  count   2356.00000
# mean     245.68325
# std      209.37127
# min        0.04745
# 25%       93.23675
# 50%      169.46554
# 75%      379.93472
# max      946.32915
# Name: Speed, dtype: float64
# Number of devices:  28
#                            ID    0
# 0   nm-mngd-20210518-19941862  228
# 1   nm-mngd-20210518-c22d980b  117
# 2   nm-mngd-20210518-f2242dfd  126
# 3   nm-mngd-20210519-ee6bcbb8   25
# 4   nm-mngd-20210915-3fb6ba43   71
# 5   nm-mngd-20210915-4489c8bd  135
# 6   nm-mngd-20210915-612a3db3   93
# 7   nm-mngd-20210915-8edface4   40
# 8   nm-mngd-20210915-a64ec38c   85
# 9   nm-mngd-20210923-074c086d   73
# 10  nm-mngd-20210924-1ca7f852   22
# 11  nm-mngd-20210924-48964f71  170
# 12  nm-mngd-20210924-872de77e   25
# 13  nm-mngd-20210924-8d1e98ab   86
# 14  nm-mngd-20210927-1b5896d3    2
# 15  nm-mngd-20210927-3f24e5b4   46
# 16  nm-mngd-20210927-4def23bd   28
# 17  nm-mngd-20210927-8da43959    8
# 18  nm-mngd-20210927-d8cfa28a  158
# 19  nm-mngd-20210927-f4ccde6b   14
# 20  nm-mngd-20211210-0e99d30d  128
# 21  nm-mngd-20220217-066fd54b  191
# 22  nm-mngd-20220217-23cbb217   68
# 23  nm-mngd-20220217-47373932   95
# 24  nm-mngd-20220217-d4ed546b   34
# 25  nm-mngd-20220301-fac88cb2   52
# 26  nm-mngd-20220505-23cccfed  152
# 27  nm-mngd-20220505-dcd76b53   84

# %%
hops = pd.read_csv(os.path.join(data_path, "hops_to_google.csv"))

# %%
print(hops.shape)
hops.columns
# Out:
# (613978, 4)
# Index(['Time', 'Hops', 'Measurement', 'ID'], dtype='object')

# %%
print(f"Date range: {hops.Time.min()} - {hops.Time.max()}")
# Out:
# Date range: 2022-07-31 19:00:55.937389-05:00 - 2022-08-31 18:57:02.722687-05:00

# %%
print(hops.Measurement.unique())
print("Hops summaries\n", hops.Hops.describe())
print("Number of devices: ", hops.ID.nunique())
hops.groupby(["ID"]).size().reset_index()
# Out:
# ['hops_to_google']
# Hops summaries
#  count   613978.00000
# mean        11.49859
# std          2.73526
# min          7.00000
# 25%          9.00000
# 50%         12.00000
# 75%         13.00000
# max         20.00000
# Name: Hops, dtype: float64
# Number of devices:  84
#                            ID     0
# 0   nm-mngd-20210511-9d9824d4  1706
# 1   nm-mngd-20210518-005bb669  7676
# 2   nm-mngd-20210518-0ca06c37  8565
# 3   nm-mngd-20210518-19941862  8613
# 4   nm-mngd-20210518-28abe768  8615
# 5   nm-mngd-20210518-a312bf95  7906
# 6   nm-mngd-20210518-c22d980b  8546
# 7   nm-mngd-20210518-f2242dfd  8613
# 8   nm-mngd-20210519-84594993  8612
# 9   nm-mngd-20210519-ee6bcbb8  8529
# 10  nm-mngd-20210623-1b49a7fa  3312
# 11  nm-mngd-20210915-21cdf51f  8927
# 12  nm-mngd-20210915-3fb6ba43  8912
# 13  nm-mngd-20210915-4489c8bd  8927
# 14  nm-mngd-20210915-5042f35e  8719
# 15  nm-mngd-20210915-612a3db3  8922
# 16  nm-mngd-20210915-774040d7  8887
# 17  nm-mngd-20210915-89e40819  8925
# 18  nm-mngd-20210915-8bb64c9a  2264
# 19  nm-mngd-20210915-8d4ba8df  2188
# 20  nm-mngd-20210915-8dd84998  8862
# Index(['Time', 'Query Time', 'Measurement', 'ID', 'Type'], dtype='object')

# %%
print(f"Date range: {dns.Time.min()} - {dns.Time.max()}")
# Out:
# Date range: 2022-07-31 19:00:55.937389-05:00 - 2022-08-31 18:57:02.722687-05:00

# %%
print(dns.Measurement.unique())
print(dns.Type.unique())
print("DNS summaries\n", dns["Query Time"].describe())
print("Number of devices: ", dns.ID.nunique())
dns.groupby(["ID"]).size().reset_index()
# Out:
# ['dns_latency']
# ['Avg' 'Max']
# DNS summaries
#  count   1228010.00000
# mean         68.99787
# std         245.01919
# min           2.85000
# 25%          24.40000
# 50%          39.00000
# 75%          55.00000
# max        4999.00000
# Name: Query Time, dtype: float64
# Number of devices:  84
#                            ID      0
# 0   nm-mngd-20210511-9d9824d4   3412
# 1   nm-mngd-20210518-005bb669  15364
# 2   nm-mngd-20210518-0ca06c37  17130
# 3   nm-mngd-20210518-19941862  17226
# 4   nm-mngd-20210518-28abe768  17230
# 5   nm-mngd-20210518-a312bf95  15812
# 6   nm-mngd-20210518-c22d980b  17094
# 7   nm-mngd-20210518-f2242dfd  17226
# 8   nm-mngd-20210519-84594993  17224
# 9   nm-mngd-20210519-ee6bcbb8  17058
# 10  nm-mngd-20210623-1b49a7fa   6624
# 11  nm-mngd-20210915-21cdf51f  17854
# 12  nm-mngd-20210915-3fb6ba43  17824
# 13  nm-mngd-20210915-4489c8bd  17854
# 14  nm-mngd-20210915-5042f35e  17438
# 15  nm-mngd-20210915-612a3db3  17844
# 16  nm-mngd-20210915-774040d7  17774
# 17  nm-mngd-20210915-89e40819  17850
# 18  nm-mngd-20210915-8bb64c9a   4528
# 19  nm-mngd-20210915-8d4ba8df   4376
# 20  nm-mngd-20210915-8dd84998  17724
# 21  nm-mngd-20210915-8edface4  17852
# 22  nm-mngd-20210915-9db171c4   4262
# 23  nm-mngd-20210915-a2352afe   4274
# 24  nm-mngd-20210915-a64ec38c  17832
# 25  nm-mngd-20210915-d5f18da9  13666
# 26  nm-mngd-20210915-f4b4a69b   3920
# 27  nm-mngd-20210916-d58b5bfc  13192
# 28  nm-mngd-20210923-074c086d  17786
# 29  nm-mngd-20210924-1ca7f852  17638
# 30  nm-mngd-20210924-48964f71  17840
# 31  nm-mngd-20210924-77f105f0  17406
# 32  nm-mngd-20210924-872de77e  17842
# 33  nm-mngd-20210924-8d1e98ab   4464
# 34  nm-mngd-20210924-a97dceb2   4416
# 35  nm-mngd-20210924-cbe578f4  17814
# 36  nm-mngd-20210924-fad61185   1428
# 37  nm-mngd-20210927-04dc925c  17840
# 38  nm-mngd-20210927-145c392b  17852
# 39  nm-mngd-20210927-178debb9  17852
# 40  nm-mngd-20210927-1a4f71d4  17558
# 41  nm-mngd-20210927-1aaa32b5   4474
# 42  nm-mngd-20210927-1b5896d3   2134
# 43  nm-mngd-20210927-3f24e5b4  17820
# 44  nm-mngd-20210927-4a1de38c  17848
# 45  nm-mngd-20210927-4def23bd  17836
# 46  nm-mngd-20210927-8da43959  17804
# 47  nm-mngd-20210927-9044c591  17784
# 48  nm-mngd-20210927-cc1bdfb9  17836
# 49  nm-mngd-20210927-d8cfa28a  17788
# 50  nm-mngd-20210927-f4ccde6b  17834
# 51  nm-mngd-20210927-f531ff46  17762
# 52  nm-mngd-20211006-ce55f0f2  16378
# 53  nm-mngd-20211210-0e99d30d  17794
# 54  nm-mngd-20220217-066fd54b  17842
# 55  nm-mngd-20220217-153d4573  17848
# 56  nm-mngd-20220217-23cbb217  16332
# 57  nm-mngd-20220217-47373932   4490
# 58  nm-mngd-20220217-9da01799  13832
# 59  nm-mngd-20220217-d4ed546b  17826
# 60  nm-mngd-20220218-178af0c4  17820
# 61  nm-mngd-20220218-486047bf  17776
# 62  nm-mngd-20220218-77d108b6  17738
# 63  nm-mngd-20220221-bffd128d  17850
# 64  nm-mngd-20220224-e5552881  17846
# 65  nm-mngd-20220301-fac88cb2  15002
# 66  nm-mngd-20220505-13e9adcd   4302
# 67  nm-mngd-20220505-23cccfed  17848
# 68  nm-mngd-20220505-30005b68  17162
# 69  nm-mngd-20220505-3740f507  11092
# 70  nm-mngd-20220505-4d0b6753  13152
# 71  nm-mngd-20220505-7db0ce31  15968
# 72  nm-mngd-20220505-a8149041  17854
# 73  nm-mngd-20220505-dcd76b53  17712
# 74  nm-mngd-20220506-2f996174  17844
# 75  nm-mngd-20220506-3809e1bb  17848
# 76  nm-mngd-20220506-8652c367  17816
# 77  nm-mngd-20220506-98c85a91  17804
# 78  nm-mngd-20220621-5913a3d5  14862
# 79  nm-mngd-20220621-eb793ac0  17854
# 80  nm-mngd-20220622-299d1347   1008
# 81  nm-mngd-20220622-a9810b6f   4400
# 82  nm-mngd-20220623-59224a4d  17852
# 83  nm-mngd-20220628-07c02d28  17138

# %%
devices = pd.read_csv(os.path.join(data_path, "device_count.csv"))

# %%
print(devices.shape)
devices.columns
# Out:
# (607957, 4)
# Index(['Time', 'No. of Devices', 'Measurement', 'ID'], dtype='object')

# %%
print(f"Date range: {devices.Time.min()} - {devices.Time.max()}")
# Out:
# Date range: 2022-07-31 19:00:55.937389-05:00 - 2022-08-31 18:57:02.722687-05:00

# %%
print(devices.Measurement.unique())
print("Device count summaries\n", devices["No. of Devices"].describe())
print("Number of devices: ", devices.ID.nunique())
devices.groupby(["ID"]).size().reset_index()
# Out:
# ['connected_devices_arp']
# Device count summaries
#  count   607957.00000
# mean         9.34536
# std          7.45526
# min          1.00000
# 25%          4.00000
# 50%          7.00000
# 75%         11.00000
# max         45.00000
# Name: No. of Devices, dtype: float64
# Number of devices:  83
#                            ID     0
# 0   nm-mngd-20210511-9d9824d4  1706
# 1   nm-mngd-20210518-005bb669  7676
# 2   nm-mngd-20210518-0ca06c37  8567
# 3   nm-mngd-20210518-19941862  8614
# 4   nm-mngd-20210518-28abe768  8615
# 5   nm-mngd-20210518-c22d980b  8547
# 6   nm-mngd-20210518-f2242dfd  8615
# 7   nm-mngd-20210519-84594993  8612
# 8   nm-mngd-20210519-ee6bcbb8  8605
# 9   nm-mngd-20210623-1b49a7fa  3312
# 10  nm-mngd-20210915-21cdf51f  8927
# 11  nm-mngd-20210915-3fb6ba43  8912
# 12  nm-mngd-20210915-4489c8bd  8927
# 13  nm-mngd-20210915-5042f35e  8924
# 14  nm-mngd-20210915-612a3db3  8922
# 15  nm-mngd-20210915-774040d7  8888
# 16  nm-mngd-20210915-89e40819  8926
